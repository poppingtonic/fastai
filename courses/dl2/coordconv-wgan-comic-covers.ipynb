# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## WGAN

# %%
from fastai.conv_learner import *
from fastai.dataset import *
import gzip

# %%
PATH = Path('data/comix-gan')
IMG_PATH = PATH/'images/5'
CSV_PATH = PATH/'files.csv'
TMP_PATH = PATH/'tmp'
TMP_PATH.mkdir(exist_ok=True)

# %%
files = PATH.glob("images/**/*.jpg")
with CSV_PATH.open('w') as fo:
    for f in files: fo.write(f'{f.relative_to(IMG_PATH)},0\n')

# %%
class AddCoords(nn.Module):

    def __init__(self, with_r=False):
        super().__init__()
        self.with_r = with_r

    def forward(self, input_tensor):
        """
        Args:
            input_tensor: shape(batch, channel, x_dim, y_dim)
        """
        batch_size, _, x_dim, y_dim = input_tensor.size()

        xx_channel = torch.arange(x_dim).repeat(1, y_dim, 1)
        yy_channel = torch.arange(y_dim).repeat(1, x_dim, 1).transpose(1, 2)

        xx_channel = xx_channel.float() / (x_dim - 1)
        yy_channel = yy_channel.float() / (y_dim - 1)

        xx_channel = xx_channel * 2 - 1
        yy_channel = yy_channel * 2 - 1

        xx_channel = xx_channel.repeat(batch_size, 1, 1, 1).transpose(2, 3)
        yy_channel = yy_channel.repeat(batch_size, 1, 1, 1).transpose(2, 3)

        ret = torch.cat([
            input_tensor,
            xx_channel.type_as(input_tensor),
            yy_channel.type_as(input_tensor)], dim=1)

        if self.with_r:
            rr = torch.sqrt(torch.pow(xx_channel - 0.5, 2) + torch.pow(yy_channel - 0.5, 2))
            ret = torch.cat([ret, rr], dim=1)

        return ret

# %%
class CoordConv(nn.Module):
    def __init__(self, in_chan, out_chan, with_r=False, **kwargs):
        super().__init__()
        self.addcoords = AddCoords(with_r=with_r)
        self.conv = nn.Conv2d(in_chan + 2, out_chan, **kwargs)

    def forward(self, x):
        ret = self.addcoords(x)
        ret = self.conv(ret)
        return ret

# %%
class SeparableConv2D(nn.Module):
    def __init__(self, in_chan, out_chan, kernel_size=1, stride=1, padding=0, dilation=1, bias=False):
        super(SeparableConv2D, self).__init__()
        self.conv1 = nn.Conv2d(in_chan, in_chan, kernel_size, stride, padding, dilation, groups=in_chan, bias=bias)
        self.pointwise = nn.Conv2d(in_chan, out_chan, 1, 1, 0, 1, 1, bias=bias)

    def forward(self, x):
        return self.pointwise(self.conv1(x))

# %%
class ConvBlock(nn.Module):
    def __init__(self, ni, no, ks, stride, bn=True, pad=None):
        super().__init__()
        if pad is None: pad = ks//2//stride
        self.conv = CoordConv(ni, no, kernel_size=ks, stride=stride, padding=pad, bias=False)
        self.bn = nn.BatchNorm2d(no) if bn else None
        self.relu = nn.LeakyReLU(0.2, inplace=True)
    
    def forward(self, x):
        x = self.relu(self.conv(x))
        return self.bn(x) if self.bn else x

# %%
class DCGAN_D(nn.Module):
    def __init__(self, isize, nc, ndf, n_extra_layers=0):
        super().__init__()
        assert isize % 16 == 0, "isize has to be a multiple of 16"

        self.initial = ConvBlock(nc, ndf, 4, 2, bn=False)
        csize,cndf = isize/2,ndf
        self.extra = nn.Sequential(*[ConvBlock(cndf, cndf, 3, 1)
                                    for t in range(n_extra_layers)])

        pyr_layers = []
        while csize > 4:
            pyr_layers.append(ConvBlock(cndf, cndf*2, 4, 2))
            cndf *= 2; csize /= 2
        self.pyramid = nn.Sequential(*pyr_layers)
        
        self.final = CoordConv(cndf, 1, kernel_size=4, padding=0, bias=False)

    def forward(self, input):
        x = self.initial(input)
        x = self.extra(x)
        x = self.pyramid(x)
        return self.final(x).mean(0).view(1)

# %%
class DeconvBlock(nn.Module):
    def __init__(self, ni, no, ks, stride, pad, bn=True):
        super().__init__()
        self.conv = nn.ConvTranspose2d(ni, no, ks, stride, padding=pad, bias=False)
        self.bn = nn.BatchNorm2d(no)
        self.relu = nn.ReLU(inplace=True)
        
    def forward(self, x):
        x = self.relu(self.conv(x))
        return self.bn(x) if self.bn else x

# %%
class DCGAN_G(nn.Module):
    def __init__(self, isize, nz, nc, ngf, n_extra_layers=0):
        super().__init__()
        assert isize % 16 == 0, "isize has to be a multiple of 16"

        cngf, tisize = ngf//2, 4
        while tisize!=isize: cngf*=2; tisize*=2
        layers = [DeconvBlock(nz, cngf, 4, 1, 0)]

        csize, cndf = 4, cngf
        while csize < isize//2:
            layers.append(DeconvBlock(cngf, cngf//2, 4, 2, 1))
            cngf //= 2; csize *= 2

        layers += [DeconvBlock(cngf, cngf, 3, 1, 1) for t in range(n_extra_layers)]
        layers.append(nn.ConvTranspose2d(cngf, nc, 4, 2, 1, bias=False))
        self.features = nn.Sequential(*layers)

    def forward(self, input): return F.tanh(self.features(input))

# %%
bs,sz,nz = 64,64,100

# %%
tfms = tfms_from_stats(inception_stats, sz)
md = ImageClassifierData.from_csv(PATH, 'images/5', CSV_PATH, tfms=tfms, bs=128,
                                  skip_header=False, continuous=True)

# %%
md = md.resize(64)
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))

# %%
x,_ = next(iter(md.val_dl))

# %%
plt.imshow(md.trn_ds.denorm(x)[2]);

# %%
netG = DCGAN_G(sz, nz, 3, 64, 1).cuda()
netD = DCGAN_D(sz, 3, 64, 1).cuda()

# %%
def create_noise(b): return V(torch.zeros(b, nz, 1, 1).normal_(0, 1))

# %%
preds = netG(create_noise(4))
pred_ims = md.trn_ds.denorm(preds)

fig, axes = plt.subplots(2, 2, figsize=(6, 6))
for i,ax in enumerate(axes.flat): ax.imshow(pred_ims[i])

# %%
def gallery(x, nc=3):
    n,h,w,c = x.shape
    nr = n//nc
    assert n == nr*nc
    return (x.reshape(nr, nc, h, w, c)
              .swapaxes(1,2)
              .reshape(h*nr, w*nc, c))

# %%
optimizerD = optim.RMSprop(netD.parameters(), lr = 1e-4)
optimizerG = optim.RMSprop(netG.parameters(), lr = 1e-4)

# %%
def train(niter, first=True):
    gen_iterations = 0
    for epoch in trange(niter):
        netD.train(); netG.train()
        data_iter = iter(md.trn_dl)
        i,n = 0,len(md.trn_dl)
        with tqdm(total=n) as pbar:
            while i < n:
                set_trainable(netD, True)
                set_trainable(netG, False)
                d_iters = 100 if (first and (gen_iterations < 25) or (gen_iterations % 500 == 0)) else 5
                j = 0
                while (j < d_iters) and (i < n):
                    j += 1; i += 1
                    for p in netD.parameters(): p.data.clamp_(-0.01, 0.01)
                    real = V(next(data_iter)[0])
                    real_loss = netD(real)
                    fake = netG(create_noise(real.size(0)))
                    fake_loss = netD(V(fake.data))
                    netD.zero_grad()
                    lossD = real_loss-fake_loss
                    lossD.backward()
                    optimizerD.step()
                    pbar.update()

                set_trainable(netD, False)
                set_trainable(netG, True)
                netG.zero_grad()
                lossG = netD(netG(create_noise(bs)))
                lossG.backward()
                optimizerG.step()
                gen_iterations += 1
            
        print(f'Loss_D {to_np(lossD)}; Loss_G {to_np(lossG)}; '
              f'D_real {to_np(real_loss)}; Loss_D_fake {to_np(fake_loss)}')

# %%
torch.backends.cudnn.benchmark=True

# %%
cyc = 1000
train(cyc, False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-b100a5a06961> in <module>()
#       1 cyc = 1000
# ----> 2 train(cyc, False)
#
# <ipython-input-59-fdb2957e7c2a> in train(niter, first)
#      15                     for p in netD.parameters(): p.data.clamp_(-0.01, 0.01)
#      16                     real = V(next(data_iter)[0])
# ---> 17                     real_loss = netD(real)
#      18                     fake = netG(create_noise(real.size(0)))
#      19                     fake_loss = netD(V(fake.data))
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-46-9ef99450beb7> in forward(self, input)
#      18
#      19     def forward(self, input):
# ---> 20         x = self.initial(input)
#      21         x = self.extra(x)
#      22         x = self.pyramid(x)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-45-1cd8c4f9b44e> in forward(self, x)
#       8
#       9     def forward(self, x):
# ---> 10         x = self.relu(self.conv(x))
#      11         return self.bn(x) if self.bn else x
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-43-6869e266ee15> in forward(self, x)
#       6
#       7     def forward(self, x):
# ----> 8         ret = self.addcoords(x)
#       9         ret = self.conv(ret)
#      10         return ret
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-42-f9e3e90d0723> in forward(self, input_tensor)
#      26         ret = torch.cat([
#      27             input_tensor,
# ---> 28             xx_channel.type_as(input_tensor),
#      29             yy_channel.type_as(input_tensor)], dim=1)
#      30
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/tensor.py in type_as(self, tensor)
#      39             tensor (Tensor): the tensor with the desired type
#      40         """
# ---> 41         return self.type(tensor.type())
#      42
#      43     def cpu(self):
#
# TypeError: type() missing 1 required positional argument: 't'

# %%
# %debug
# Out:
# > /home/bmn/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/tensor.py(41)type_as()
#      39             tensor (Tensor): the tensor with the desired type
#      40         """
# ---> 41         return self.type(tensor.type())
#      42
#      43     def cpu(self):
#
# ipdb> tensor.type(
# *** SyntaxError: unexpected EOF while parsing
# ipdb> tensor.type()
# *** TypeError: type() missing 1 required positional argument: 't'
# ipdb> l
#      36             self.type(tensor.type())
#      37
#      38         Params:
#      39             tensor (Tensor): the tensor with the desired type
#      40         """
# ---> 41         return self.type(tensor.type())
#      42
#      43     def cpu(self):
#      44         r"""Returns a CPU copy of this tensor if it's not already on the CPU"""
#      45         return self.type(getattr(torch, self.__class__.__name__))
#      46
#
# ipdb> tensor
# Variable containing:
# ( 0 , 0 ,.,.) =
#   0.5529  0.5529  0.5451  ...   0.5765  0.6078  0.6314
#   0.5529  0.5529  0.5451  ...   0.5686  0.5922  0.6078
#   0.5529  0.5529  0.5451  ...   0.5451  0.5686  0.5922
#            ...             ⋱             ...
#  -1.0000 -1.0000 -0.9922  ...  -1.0000 -1.0000 -1.0000
#  -0.9529 -0.9294 -0.9294  ...  -1.0000 -1.0000 -1.0000
#  -1.0000 -0.9608 -1.0000  ...  -0.9922 -1.0000 -1.0000
#
# ( 0 , 1 ,.,.) =
#  -0.7412 -0.7412 -0.7412  ...  -0.7490 -0.7725 -0.7804
#  -0.7412 -0.7412 -0.7412  ...  -0.7490 -0.7569 -0.7725
#  -0.7412 -0.7412 -0.7412  ...  -0.7333 -0.7490 -0.7569
#            ...             ⋱             ...
#  -0.9373 -0.9059 -0.8588  ...  -0.9373 -0.9137 -0.9059
#  -0.8196 -0.7961 -0.7961  ...  -0.9137 -0.9137 -0.9216
#  -0.9373 -0.8431 -0.8510  ...  -0.9216 -0.9294 -0.9373
#
# ( 0 , 2 ,.,.) =
#  -0.7569 -0.7569 -0.7569  ...  -0.7725 -0.7725 -0.7725
#  -0.7569 -0.7569 -0.7569  ...  -0.7725 -0.7725 -0.7725
#  -0.7569 -0.7569 -0.7569  ...  -0.7725 -0.7725 -0.7725
#            ...             ⋱             ...
#  -0.8588 -0.8275 -0.7804  ...  -0.8353 -0.8118 -0.8039
#  -0.7412 -0.7176 -0.7176  ...  -0.8118 -0.8118 -0.8196
#  -0.9373 -0.8196 -0.8196  ...  -0.8510 -0.8588 -0.8667
#       ⋮
#
# ( 1 , 0 ,.,.) =
#   0.6000  0.6235  0.5216  ...  -0.2706 -0.2000 -0.0745
#   0.6000  0.6235  0.5294  ...  -0.4588 -0.4745 -0.1294
#   0.6549  0.6549  0.5686  ...  -0.6000 -0.6706 -0.3255
#            ...             ⋱             ...
#   0.6706  0.7882  0.6941  ...   0.7412  0.6235 -0.1216
#   0.6706  0.7412  0.6471  ...   0.7020  0.5686 -0.1922
#   0.7961  0.7882  0.6549  ...   0.7176  0.5922 -0.1843
#
# ( 1 , 1 ,.,.) =
#   0.4980  0.5294  0.4118  ...  -0.3490 -0.3882 -0.4667
#   0.4902  0.5137  0.3882  ...  -0.4902 -0.6078 -0.4588
#   0.4980  0.5137  0.3882  ...  -0.5843 -0.7412 -0.5922
#            ...             ⋱             ...
#   0.5686  0.6314  0.4824  ...   0.6784  0.4196 -0.4275
#   0.5686  0.5843  0.4353  ...   0.6549  0.4039 -0.4588
#   0.6941  0.6314  0.4431  ...   0.6706  0.4275 -0.4431
#
# ( 1 , 2 ,.,.) =
#  -0.4039 -0.3490 -0.4275  ...  -0.9137 -0.6863 -0.5216
#  -0.3490 -0.3098 -0.3961  ...  -0.9686 -0.8275 -0.4275
#  -0.2627 -0.2549 -0.3490  ...  -0.9686 -0.8745 -0.4667
#            ...             ⋱             ...
#  -0.4588 -0.1294 -0.0588  ...  -0.2941 -0.1843 -0.6706
#  -0.4588 -0.1765 -0.1059  ...  -0.2392 -0.2157 -0.7490
#  -0.3333 -0.1294 -0.0980  ...  -0.1922 -0.1922 -0.7647
#       ⋮
#
# ( 2 , 0 ,.,.) =
#  -0.7725 -0.8275 -0.7098  ...  -0.6784 -0.7176 -0.7490
#  -0.8275 -0.8588 -0.7255  ...  -0.6941 -0.7255 -0.7725
#  -0.7725 -0.7882 -0.6941  ...  -0.6078 -0.6627 -0.7255
#            ...             ⋱             ...
#  -0.5059 -0.4510 -0.4510  ...  -0.4902 -0.7098 -0.7647
#  -0.5373 -0.5059 -0.3647  ...  -0.4510 -0.6627 -0.8431
#  -0.6000 -0.5843 -0.3569  ...  -0.5765 -0.7569 -0.9137
#
# ( 2 , 1 ,.,.) =
#  -0.8510 -0.8980 -0.7961  ...  -0.8275 -0.8510 -0.8824
#  -0.9137 -0.9451 -0.8275  ...  -0.8431 -0.8824 -0.9137
#  -0.8588 -0.8902 -0.8118  ...  -0.7647 -0.8196 -0.8745
#            ...             ⋱             ...
#  -0.4824 -0.4275 -0.4275  ...  -0.4745 -0.7098 -0.7647
#  -0.5216 -0.4902 -0.3333  ...  -0.4039 -0.6392 -0.8196
#  -0.5765 -0.5608 -0.3333  ...  -0.4980 -0.7020 -0.8667
#
# ( 2 , 2 ,.,.) =
#  -0.8667 -0.9373 -0.8431  ...  -0.8118 -0.8039 -0.8353
#  -0.9451 -0.9765 -0.8902  ...  -0.8745 -0.8745 -0.9137
#  -0.8902 -0.9373 -0.8667  ...  -0.8510 -0.8902 -0.9294
#            ...             ⋱             ...
#  -0.6157 -0.5608 -0.5608  ...  -0.5765 -0.8039 -0.8588
#  -0.6314 -0.5922 -0.4431  ...  -0.4824 -0.7098 -0.8902
#  -0.6471 -0.6314 -0.4039  ...  -0.5608 -0.7569 -0.8980
# ...
#       ⋮
#
# (125, 0 ,.,.) =
#   0.2235  0.2157  0.1843  ...   0.2392  0.2549  0.2706
#   0.3804  0.3176  0.2157  ...   0.3020  0.3176  0.3333
#   0.5137  0.4353  0.2941  ...   0.3412  0.3333  0.3333
#            ...             ⋱             ...
#   0.8980  0.9059  0.9059  ...   0.6235  0.6471  0.6627
#   0.9294  0.9451  0.9451  ...   0.6235  0.6471  0.6471
#   0.9059  0.9137  0.9137  ...   0.6000  0.6157  0.6314
#
# (125, 1 ,.,.) =
#  -0.0431 -0.0431 -0.0745  ...  -0.0902 -0.0745 -0.0588
#   0.0980  0.0510 -0.0431  ...  -0.0275 -0.0118  0.0039
#   0.2314  0.1765  0.0588  ...   0.0118  0.0196  0.0196
#            ...             ⋱             ...
#   0.3490  0.3725  0.3961  ...   0.0196 -0.0118 -0.0353
#   0.3490  0.3725  0.4039  ...   0.0275 -0.0039 -0.0196
#   0.2863  0.3098  0.3333  ...   0.0196 -0.0039 -0.0118
#
# (125, 2 ,.,.) =
#  -0.1216 -0.1137 -0.1294  ...  -0.2627 -0.2471 -0.2314
#   0.0039 -0.0431 -0.1137  ...  -0.2000 -0.1843 -0.1686
#   0.1059  0.0588 -0.0275  ...  -0.1843 -0.1843 -0.1843
#            ...             ⋱             ...
#  -0.4039 -0.3882 -0.3412  ...  -0.3882 -0.3725 -0.3647
#  -0.3961 -0.3647 -0.3098  ...  -0.3647 -0.3490 -0.3412
#  -0.4353 -0.3961 -0.3647  ...  -0.3647 -0.3412 -0.3255
#       ⋮
#
# (126, 0 ,.,.) =
#   0.4745  0.8510  0.9059  ...   1.0000  1.0000  0.7569
#   0.0902  0.5922  0.9216  ...   1.0000  1.0000  0.6235
#  -0.1922  0.2863  0.8431  ...   1.0000  0.9216  0.3490
#            ...             ⋱             ...
#   0.4353  0.5451  0.6000  ...   0.2078  0.0902  0.0510
#   0.2784  0.4980  0.4980  ...   0.2235  0.1451  0.0275
#   0.4980  0.4902  0.2157  ...   0.2706  0.2549  0.0902
#
# (126, 1 ,.,.) =
#   0.8118  1.0000  1.0000  ...   0.8824  0.9451  0.9451
#   0.4510  0.8118  1.0000  ...   0.9216  0.9294  0.8745
#   0.2078  0.5529  1.0000  ...   0.9843  0.8353  0.7176
#            ...             ⋱             ...
#   0.0824  0.1765  0.2078  ...  -0.0980 -0.1922 -0.2314
#  -0.0510  0.1373  0.1059  ...  -0.0431 -0.1216 -0.2157
#   0.1686  0.1373 -0.1529  ...   0.0275  0.0275 -0.1451
#
# (126, 2 ,.,.) =
#   1.0000  0.5373  0.1059  ...   0.0431  0.0902  0.4902
#   0.7333  0.3490  0.1686  ...   0.1451  0.1529  0.4902
#   0.4196  0.1529  0.1843  ...   0.3333  0.2157  0.4667
#            ...             ⋱             ...
#   0.1373  0.2549  0.3020  ...  -0.0902 -0.3020 -0.4353
#  -0.0196  0.2157  0.2000  ...  -0.0510 -0.2157 -0.4353
#   0.2000  0.1922 -0.0745  ...   0.0118 -0.0824 -0.3490
#       ⋮
#
# (127, 0 ,.,.) =
#  -1.0000 -1.0000 -0.5451  ...  -0.8667 -0.9529 -1.0000
#  -0.9686 -1.0000 -0.6392  ...  -0.9137 -1.0000 -1.0000
#  -1.0000 -1.0000 -0.6627  ...  -0.9137 -0.9529 -1.0000
#            ...             ⋱             ...
#  -1.0000 -1.0000 -1.0000  ...  -0.9451 -1.0000 -0.9137
#  -0.9922 -1.0000 -1.0000  ...  -0.8745 -0.9686 -0.9843
#  -1.0000 -0.9922 -1.0000  ...  -0.9765 -0.9922 -1.0000
#
# (127, 1 ,.,.) =
#  -0.9686 -0.9765 -0.4980  ...  -1.0000 -0.9529 -0.9451
#  -0.8824 -0.9686 -0.5922  ...  -1.0000 -0.9843 -0.9529
#  -0.9686 -0.9765 -0.5922  ...  -1.0000 -0.8824 -0.9451
#            ...             ⋱             ...
#  -0.9765 -0.9843 -0.9529  ...  -0.9451 -1.0000 -0.9137
#  -0.9294 -0.9608 -0.9922  ...  -0.8745 -0.9686 -0.9843
#  -0.9765 -0.9529 -0.9922  ...  -0.9765 -0.9922 -1.0000
#
# (127, 2 ,.,.) =
#  -1.0000 -1.0000 -0.5137  ...  -0.9529 -0.9529 -0.9765
#  -0.9137 -1.0000 -0.5922  ...  -0.9843 -0.9922 -1.0000
#  -0.9843 -0.9843 -0.6000  ...  -0.9608 -0.9059 -1.0000
#            ...             ⋱             ...
#  -0.9608 -0.9686 -0.9373  ...  -0.9451 -1.0000 -0.9137
#  -0.9137 -0.9451 -0.9686  ...  -0.8745 -0.9686 -0.9843
#  -0.9529 -0.9294 -0.9686  ...  -0.9765 -0.9922 -1.0000
# [torch.cuda.FloatTensor of size 128x3x64x64 (GPU 0)]

# %%
fixed_noise = create_noise(bs)

# %%
set_trainable(netD, True)
set_trainable(netG, True)
optimizerD = optim.RMSprop(netD.parameters(), lr = 1e-5)
optimizerG = optim.RMSprop(netG.parameters(), lr = 1e-5)

# %%
cyc = 5000
train(cyc, False)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# 100%|██████████| 8/8 [00:01<00:00,  6.80it/s]
# Loss_D [-0.99271]; Loss_G [0.60824]; D_real [-0.57809]; Loss_D_fake [0.41463]
# 100%|██████████| 8/8 [00:01<00:00,  5.38it/s]s/it]
# Loss_D [-1.09537]; Loss_G [0.52932]; D_real [-0.59873]; Loss_D_fake [0.49664]
# 100%|██████████| 8/8 [00:01<00:00,  6.05it/s]s/it]
# Loss_D [-1.09969]; Loss_G [0.58925]; D_real [-0.64081]; Loss_D_fake [0.45887]
# 100%|██████████| 8/8 [00:01<00:00,  6.59it/s]s/it]
# Loss_D [-0.90113]; Loss_G [0.62432]; D_real [-0.63089]; Loss_D_fake [0.27023]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s]s/it]
# Loss_D [-1.09916]; Loss_G [0.57]; D_real [-0.57592]; Loss_D_fake [0.52324]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s]s/it]
# Loss_D [-0.73865]; Loss_G [0.37863]; D_real [-0.25055]; Loss_D_fake [0.4881]
# 100%|██████████| 8/8 [00:01<00:00,  6.49it/s]s/it]
# Loss_D [-1.02917]; Loss_G [0.4872]; D_real [-0.42186]; Loss_D_fake [0.60731]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s]s/it]
# Loss_D [-1.15909]; Loss_G [0.56926]; D_real [-0.56078]; Loss_D_fake [0.59831]
# 100%|██████████| 8/8 [00:01<00:00,  6.50it/s]s/it]
# Loss_D [-1.09454]; Loss_G [0.54762]; D_real [-0.58688]; Loss_D_fake [0.50767]
# 100%|██████████| 8/8 [00:01<00:00,  6.40it/s]s/it]
# Loss_D [-1.09943]; Loss_G [0.48686]; D_real [-0.51281]; Loss_D_fake [0.58662]
# 100%|██████████| 8/8 [00:01<00:00,  6.52it/s]2s/it]
# Loss_D [-1.06603]; Loss_G [0.43074]; D_real [-0.45806]; Loss_D_fake [0.60797]
# 100%|██████████| 8/8 [00:01<00:00,  6.59it/s]1s/it]
# Loss_D [-0.91768]; Loss_G [0.59759]; D_real [-0.57722]; Loss_D_fake [0.34046]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]0s/it]
# Loss_D [-0.58169]; Loss_G [0.37674]; D_real [-0.24806]; Loss_D_fake [0.33364]
# 100%|██████████| 8/8 [00:01<00:00,  6.51it/s]1s/it]
# Loss_D [-1.1291]; Loss_G [0.57278]; D_real [-0.5382]; Loss_D_fake [0.5909]
# 100%|██████████| 8/8 [00:01<00:00,  6.55it/s]1s/it]
# Loss_D [-1.03249]; Loss_G [0.61704]; D_real [-0.59429]; Loss_D_fake [0.4382]
# 100%|██████████| 8/8 [00:01<00:00,  6.49it/s]0s/it]
# Loss_D [-0.94208]; Loss_G [0.56162]; D_real [-0.50202]; Loss_D_fake [0.44006]
# 100%|██████████| 8/8 [00:01<00:00,  6.48it/s]0s/it]
# Loss_D [-0.99818]; Loss_G [0.52888]; D_real [-0.56752]; Loss_D_fake [0.43067]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s]0s/it]
# Loss_D [-1.08398]; Loss_G [0.52709]; D_real [-0.55111]; Loss_D_fake [0.53287]
# 100%|██████████| 8/8 [00:01<00:00,  6.49it/s]0s/it]
# Loss_D [-0.6547]; Loss_G [0.14236]; D_real [-0.03429]; Loss_D_fake [0.62041]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s]9s/it]
# Loss_D [-0.92015]; Loss_G [0.32584]; D_real [-0.34695]; Loss_D_fake [0.57319]
# 100%|██████████| 8/8 [00:01<00:00,  6.47it/s]9s/it]
# Loss_D [-0.88636]; Loss_G [0.35891]; D_real [-0.23437]; Loss_D_fake [0.65199]
# 100%|██████████| 8/8 [00:01<00:00,  6.46it/s]9s/it]
# Loss_D [-1.07126]; Loss_G [0.56948]; D_real [-0.52142]; Loss_D_fake [0.54984]
# 100%|██████████| 8/8 [00:01<00:00,  6.48it/s]9s/it]
# Loss_D [-1.00492]; Loss_G [0.61351]; D_real [-0.61365]; Loss_D_fake [0.39127]
# 100%|██████████| 8/8 [00:01<00:00,  6.51it/s]9s/it]
# Loss_D [-0.41297]; Loss_G [-0.00499]; D_real [0.07999]; Loss_D_fake [0.49296]
# 100%|██████████| 8/8 [00:01<00:00,  6.41it/s]9s/it]
# Loss_D [-0.99787]; Loss_G [0.48074]; D_real [-0.44948]; Loss_D_fake [0.54838]
# 100%|██████████| 8/8 [00:01<00:00,  6.41it/s]9s/it]
# Loss_D [-0.80809]; Loss_G [0.24942]; D_real [-0.27065]; Loss_D_fake [0.53744]
# 100%|██████████| 8/8 [00:01<00:00,  6.45it/s]9s/it]
# Loss_D [-0.81025]; Loss_G [0.06352]; D_real [-0.16354]; Loss_D_fake [0.64671]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s]8s/it]
# Loss_D [-1.01924]; Loss_G [0.45138]; D_real [-0.4491]; Loss_D_fake [0.57014]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s]8s/it]
# Loss_D [-1.05178]; Loss_G [0.50948]; D_real [-0.45573]; Loss_D_fake [0.59604]
# 100%|██████████| 8/8 [00:01<00:00,  6.42it/s]8s/it]
# Loss_D [-1.00431]; Loss_G [0.61212]; D_real [-0.58166]; Loss_D_fake [0.42265]
# 100%|██████████| 8/8 [00:01<00:00,  6.41it/s]8s/it]
# Loss_D [-0.87262]; Loss_G [0.55006]; D_real [-0.45387]; Loss_D_fake [0.41875]
# 100%|██████████| 8/8 [00:01<00:00,  6.38it/s]8s/it]
# Loss_D [-0.9699]; Loss_G [0.62397]; D_real [-0.6305]; Loss_D_fake [0.3394]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s]8s/it]
# Loss_D [-0.90298]; Loss_G [0.48558]; D_real [-0.46839]; Loss_D_fake [0.43459]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s]8s/it]
# Loss_D [-1.20286]; Loss_G [0.58651]; D_real [-0.68001]; Loss_D_fake [0.52286]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s]8s/it]
# Loss_D [-1.06771]; Loss_G [0.51338]; D_real [-0.53545]; Loss_D_fake [0.53226]
# 100%|██████████| 8/8 [00:01<00:00,  6.48it/s]8s/it]
# Loss_D [-0.93153]; Loss_G [0.21874]; D_real [-0.32364]; Loss_D_fake [0.60789]
# 100%|██████████| 8/8 [00:01<00:00,  6.39it/s]8s/it]
# Loss_D [-0.90627]; Loss_G [0.16985]; D_real [-0.28607]; Loss_D_fake [0.6202]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s]8s/it]
# Loss_D [-0.24756]; Loss_G [0.46996]; D_real [0.36745]; Loss_D_fake [0.61501]
# 100%|██████████| 8/8 [00:01<00:00,  6.39it/s]8s/it]
# Loss_D [-0.95418]; Loss_G [0.57936]; D_real [-0.59609]; Loss_D_fake [0.35809]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s]8s/it]
# Loss_D [-0.8671]; Loss_G [0.52447]; D_real [-0.47379]; Loss_D_fake [0.39331]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s]8s/it]
# Loss_D [-0.7291]; Loss_G [0.18177]; D_real [-0.23374]; Loss_D_fake [0.49536]
# 100%|██████████| 8/8 [00:01<00:00,  6.40it/s]8s/it]
# Loss_D [-0.45892]; Loss_G [-0.02461]; D_real [-0.047]; Loss_D_fake [0.41191]
# 100%|██████████| 8/8 [00:01<00:00,  6.42it/s]8s/it]
# Loss_D [-1.19573]; Loss_G [0.60146]; D_real [-0.6304]; Loss_D_fake [0.56532]
# 100%|██████████| 8/8 [00:01<00:00,  6.45it/s]8s/it]
# Loss_D [-0.84762]; Loss_G [0.31087]; D_real [-0.36881]; Loss_D_fake [0.47881]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s]8s/it]
# Loss_D [-0.95308]; Loss_G [0.28397]; D_real [-0.31457]; Loss_D_fake [0.63851]
# 100%|██████████| 8/8 [00:01<00:00,  6.42it/s]8s/it]
# Loss_D [-1.10429]; Loss_G [0.6363]; D_real [-0.66]; Loss_D_fake [0.4443]
# 100%|██████████| 8/8 [00:01<00:00,  6.42it/s]8s/it]
# Loss_D [-1.14637]; Loss_G [0.61076]; D_real [-0.66244]; Loss_D_fake [0.48393]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]8s/it]
# Loss_D [-0.98793]; Loss_G [0.51983]; D_real [-0.57002]; Loss_D_fake [0.4179]
# 100%|██████████| 8/8 [00:01<00:00,  4.88it/s]8s/it]
# Loss_D [-0.9118]; Loss_G [0.26591]; D_real [-0.34727]; Loss_D_fake [0.56453]
# 100%|██████████| 8/8 [00:01<00:00,  6.43it/s]9s/it]
# Loss_D [-0.86901]; Loss_G [0.15897]; D_real [-0.2349]; Loss_D_fake [0.6341]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s]9s/it]
# Loss_D [-1.05968]; Loss_G [0.41686]; D_real [-0.49506]; Loss_D_fake [0.56463]
# 100%|██████████| 8/8 [00:01<00:00,  6.33it/s]9s/it]
# Loss_D [-0.9662]; Loss_G [0.45132]; D_real [-0.42883]; Loss_D_fake [0.53738]
# 100%|██████████| 8/8 [00:02<00:00,  4.39it/s]9s/it]
# Loss_D [-1.01133]; Loss_G [0.49901]; D_real [-0.49351]; Loss_D_fake [0.51782]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s]1s/it]
# Loss_D [-1.15403]; Loss_G [0.52215]; D_real [-0.53686]; Loss_D_fake [0.61717]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s]1s/it]
# Loss_D [-0.94611]; Loss_G [0.2367]; D_real [-0.37419]; Loss_D_fake [0.57191]
# 100%|██████████| 8/8 [00:01<00:00,  6.39it/s]1s/it]
# Loss_D [-1.12826]; Loss_G [0.53601]; D_real [-0.53409]; Loss_D_fake [0.59417]
# 100%|██████████| 8/8 [00:01<00:00,  6.37it/s]1s/it]
# Loss_D [-1.09775]; Loss_G [0.51731]; D_real [-0.54984]; Loss_D_fake [0.54791]
# 100%|██████████| 8/8 [00:01<00:00,  6.47it/s]1s/it]
# Loss_D [-1.17954]; Loss_G [0.60651]; D_real [-0.60731]; Loss_D_fake [0.57223]
# 100%|██████████| 8/8 [00:01<00:00,  6.42it/s]1s/it]
# Loss_D [-1.11968]; Loss_G [0.47012]; D_real [-0.59228]; Loss_D_fake [0.5274]
# 100%|██████████| 8/8 [00:01<00:00,  4.93it/s]1s/it]
# Loss_D [-1.06266]; Loss_G [0.29738]; D_real [-0.44858]; Loss_D_fake [0.61408]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]2s/it]
# Loss_D [-0.67112]; Loss_G [0.10057]; D_real [-0.03008]; Loss_D_fake [0.64104]
# 100%|██████████| 8/8 [00:01<00:00,  6.39it/s]2s/it]
# Loss_D [-1.08731]; Loss_G [0.49151]; D_real [-0.48589]; Loss_D_fake [0.60141]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s]2s/it]
# Loss_D [-1.02056]; Loss_G [0.49266]; D_real [-0.53185]; Loss_D_fake [0.48871]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s]2s/it]
# Loss_D [-1.12203]; Loss_G [0.48089]; D_real [-0.56086]; Loss_D_fake [0.56117]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]2s/it]
# Loss_D [-0.91531]; Loss_G [0.46519]; D_real [-0.4324]; Loss_D_fake [0.48292]
# 100%|██████████| 8/8 [00:01<00:00,  5.39it/s]2s/it]
# Loss_D [-0.98194]; Loss_G [0.45542]; D_real [-0.35298]; Loss_D_fake [0.62896]
# 100%|██████████| 8/8 [00:01<00:00,  4.80it/s]2s/it]
# Loss_D [-0.81455]; Loss_G [0.22247]; D_real [-0.26717]; Loss_D_fake [0.54738]
# 100%|██████████| 8/8 [00:01<00:00,  6.39it/s]3s/it]
# Loss_D [-1.08213]; Loss_G [0.48695]; D_real [-0.52081]; Loss_D_fake [0.56132]
# 100%|██████████| 8/8 [00:01<00:00,  4.91it/s]3s/it]
# Loss_D [-1.01036]; Loss_G [0.57097]; D_real [-0.60163]; Loss_D_fake [0.40873]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s]4s/it]
# Loss_D [-0.95873]; Loss_G [0.40019]; D_real [-0.39927]; Loss_D_fake [0.55946]
# 100%|██████████| 8/8 [00:01<00:00,  4.91it/s]4s/it]
# Loss_D [-0.77454]; Loss_G [0.24781]; D_real [-0.11655]; Loss_D_fake [0.65799]
# 100%|██████████| 8/8 [00:02<00:00,  4.35it/s]4s/it]
# Loss_D [-0.9799]; Loss_G [0.31588]; D_real [-0.38734]; Loss_D_fake [0.59255]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s]6s/it]
# Loss_D [-1.16962]; Loss_G [0.58143]; D_real [-0.61877]; Loss_D_fake [0.55085]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s]6s/it]
# Loss_D [-1.03481]; Loss_G [0.55231]; D_real [-0.57582]; Loss_D_fake [0.45898]
# 100%|██████████| 8/8 [00:01<00:00,  6.41it/s]5s/it]
# Loss_D [-1.03508]; Loss_G [0.50325]; D_real [-0.53352]; Loss_D_fake [0.50156]
# 100%|██████████| 8/8 [00:01<00:00,  5.12it/s]5s/it]
# Loss_D [-1.02769]; Loss_G [0.34579]; D_real [-0.498]; Loss_D_fake [0.52968]
# 100%|██████████| 8/8 [00:01<00:00,  5.14it/s]6s/it]
# Loss_D [-0.65123]; Loss_G [0.11725]; D_real [-0.02573]; Loss_D_fake [0.6255]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s]6s/it]
# Loss_D [-0.90499]; Loss_G [0.19508]; D_real [-0.26279]; Loss_D_fake [0.6422]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s]6s/it]
# Loss_D [-1.03549]; Loss_G [0.46515]; D_real [-0.45521]; Loss_D_fake [0.58028]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s]6s/it]
# Loss_D [-0.97534]; Loss_G [0.36176]; D_real [-0.42464]; Loss_D_fake [0.5507]
# 100%|██████████| 8/8 [00:01<00:00,  6.38it/s]6s/it]
# Loss_D [-0.99077]; Loss_G [0.47361]; D_real [-0.36587]; Loss_D_fake [0.6249]
# 100%|██████████| 8/8 [00:01<00:00,  6.33it/s]6s/it]
# Loss_D [-1.18224]; Loss_G [0.57818]; D_real [-0.60988]; Loss_D_fake [0.57236]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]6s/it]
# Loss_D [-0.91015]; Loss_G [0.40129]; D_real [-0.43635]; Loss_D_fake [0.4738]
# 100%|██████████| 8/8 [00:01<00:00,  6.44it/s]6s/it]
# Loss_D [-1.05762]; Loss_G [0.53749]; D_real [-0.49876]; Loss_D_fake [0.55886]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s]6s/it]
# Loss_D [-0.99039]; Loss_G [0.5332]; D_real [-0.46048]; Loss_D_fake [0.52991]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s]6s/it]
# Loss_D [-1.06395]; Loss_G [0.57704]; D_real [-0.59691]; Loss_D_fake [0.46704]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s]6s/it]
# Loss_D [-0.83804]; Loss_G [0.06445]; D_real [-0.28062]; Loss_D_fake [0.55743]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]6s/it]
# Loss_D [-0.71298]; Loss_G [0.21302]; D_real [-0.1227]; Loss_D_fake [0.59028]
# 100%|██████████| 8/8 [00:01<00:00,  6.37it/s]6s/it]
# Loss_D [-0.95736]; Loss_G [0.29535]; D_real [-0.33383]; Loss_D_fake [0.62353]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]5s/it]
# Loss_D [-0.92672]; Loss_G [0.38956]; D_real [-0.32596]; Loss_D_fake [0.60076]
# 100%|██████████| 8/8 [00:01<00:00,  5.68it/s]5s/it]
# Loss_D [-0.90051]; Loss_G [0.365]; D_real [-0.39867]; Loss_D_fake [0.50184]
# 100%|██████████| 8/8 [00:01<00:00,  5.60it/s]6s/it]
# Loss_D [-0.99304]; Loss_G [0.48784]; D_real [-0.44525]; Loss_D_fake [0.54779]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s]6s/it]
# Loss_D [-0.93253]; Loss_G [0.57219]; D_real [-0.56614]; Loss_D_fake [0.36638]
# 100%|██████████| 8/8 [00:01<00:00,  6.37it/s]6s/it]
# Loss_D [-0.90998]; Loss_G [0.6004]; D_real [-0.57148]; Loss_D_fake [0.33849]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s]6s/it]
# Loss_D [-0.88341]; Loss_G [0.32154]; D_real [-0.4747]; Loss_D_fake [0.40871]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s]6s/it]
# Loss_D [-0.92839]; Loss_G [0.439]; D_real [-0.42801]; Loss_D_fake [0.50038]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]6s/it]
# Loss_D [-0.91256]; Loss_G [0.53298]; D_real [-0.50034]; Loss_D_fake [0.41222]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]5s/it]
# Loss_D [-1.04737]; Loss_G [0.58944]; D_real [-0.65176]; Loss_D_fake [0.39561]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s]5s/it]
# Loss_D [-0.84226]; Loss_G [0.65132]; D_real [-0.65554]; Loss_D_fake [0.18672]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]5s/it]
# Loss_D [-1.09662]; Loss_G [0.59338]; D_real [-0.61863]; Loss_D_fake [0.47799]
# 100%|██████████| 8/8 [00:01<00:00,  6.29it/s]45s/it]
# Loss_D [-0.91547]; Loss_G [0.63267]; D_real [-0.65786]; Loss_D_fake [0.25762]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s]45s/it]
# Loss_D [-0.97628]; Loss_G [0.53877]; D_real [-0.56518]; Loss_D_fake [0.41111]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]45s/it]
# Loss_D [-1.06961]; Loss_G [0.63377]; D_real [-0.65971]; Loss_D_fake [0.4099]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s]45s/it]
# Loss_D [-0.9858]; Loss_G [0.59666]; D_real [-0.60413]; Loss_D_fake [0.38167]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s]45s/it]
# Loss_D [-0.83661]; Loss_G [0.42494]; D_real [-0.35895]; Loss_D_fake [0.47766]
# 100%|██████████| 8/8 [00:01<00:00,  6.34it/s]45s/it]
# Loss_D [-0.69963]; Loss_G [0.13063]; D_real [-0.29446]; Loss_D_fake [0.40517]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]45s/it]
# Loss_D [-0.9379]; Loss_G [0.39148]; D_real [-0.40823]; Loss_D_fake [0.52968]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]45s/it]
# Loss_D [-0.83309]; Loss_G [0.0889]; D_real [-0.23331]; Loss_D_fake [0.59977]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s]45s/it]
# Loss_D [-0.69563]; Loss_G [-0.01904]; D_real [-0.05972]; Loss_D_fake [0.63591]
# 100%|██████████| 8/8 [00:01<00:00,  5.20it/s]45s/it]
# Loss_D [-0.84438]; Loss_G [0.2585]; D_real [-0.29411]; Loss_D_fake [0.55027]
# 100%|██████████| 8/8 [00:01<00:00,  5.25it/s]45s/it]
# Loss_D [-1.11801]; Loss_G [0.50843]; D_real [-0.54813]; Loss_D_fake [0.56988]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s]46s/it]
# Loss_D [-1.11988]; Loss_G [0.61954]; D_real [-0.63705]; Loss_D_fake [0.48283]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s]46s/it]
# Loss_D [-0.97234]; Loss_G [0.59776]; D_real [-0.57576]; Loss_D_fake [0.39658]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s]46s/it]
# Loss_D [-0.88178]; Loss_G [0.46053]; D_real [-0.42867]; Loss_D_fake [0.45312]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s]46s/it]
# Loss_D [-0.74694]; Loss_G [-0.07565]; D_real [-0.14354]; Loss_D_fake [0.6034]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s]45s/it]
# Loss_D [-1.11138]; Loss_G [0.48323]; D_real [-0.5013]; Loss_D_fake [0.61008]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]45s/it]
# Loss_D [-1.0163]; Loss_G [0.43043]; D_real [-0.45546]; Loss_D_fake [0.56084]
# 100%|██████████| 8/8 [00:02<00:00,  4.42it/s]45s/it]
# Loss_D [-1.01283]; Loss_G [0.55486]; D_real [-0.61225]; Loss_D_fake [0.40058]
# 100%|██████████| 8/8 [00:01<00:00,  5.77it/s]46s/it]
# Loss_D [-1.03717]; Loss_G [0.55083]; D_real [-0.57164]; Loss_D_fake [0.46553]
# 100%|██████████| 8/8 [00:01<00:00,  6.30it/s]46s/it]
# Loss_D [-0.9394]; Loss_G [0.52035]; D_real [-0.47428]; Loss_D_fake [0.46511]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s]46s/it]
# Loss_D [-1.04718]; Loss_G [0.62073]; D_real [-0.64972]; Loss_D_fake [0.39746]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s]46s/it]
# Loss_D [-1.12454]; Loss_G [0.61219]; D_real [-0.67391]; Loss_D_fake [0.45063]
# 100%|██████████| 8/8 [00:01<00:00,  5.84it/s]46s/it]
# Loss_D [-0.94173]; Loss_G [0.54502]; D_real [-0.53555]; Loss_D_fake [0.40618]
# 100%|██████████| 8/8 [00:01<00:00,  5.28it/s]46s/it]
# Loss_D [-0.91033]; Loss_G [0.43266]; D_real [-0.35337]; Loss_D_fake [0.55697]
# 100%|██████████| 8/8 [00:01<00:00,  6.29it/s]46s/it]
# Loss_D [-1.09966]; Loss_G [0.606]; D_real [-0.57366]; Loss_D_fake [0.52599]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]46s/it]
# Loss_D [-0.83032]; Loss_G [0.63961]; D_real [-0.59394]; Loss_D_fake [0.23638]
# 100%|██████████| 8/8 [00:01<00:00,  6.36it/s]46s/it]
# Loss_D [-0.83111]; Loss_G [0.64094]; D_real [-0.64292]; Loss_D_fake [0.18819]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s]46s/it]
# Loss_D [-1.10505]; Loss_G [0.53236]; D_real [-0.60977]; Loss_D_fake [0.49527]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s]46s/it]
# Loss_D [-0.89882]; Loss_G [0.34738]; D_real [-0.40114]; Loss_D_fake [0.49768]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s]47s/it]
# Loss_D [-1.10139]; Loss_G [0.59723]; D_real [-0.61301]; Loss_D_fake [0.48838]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]47s/it]
# Loss_D [-0.96472]; Loss_G [0.55474]; D_real [-0.55805]; Loss_D_fake [0.40667]
# 100%|██████████| 8/8 [00:01<00:00,  6.37it/s]47s/it]
# Loss_D [-0.93426]; Loss_G [0.50162]; D_real [-0.55846]; Loss_D_fake [0.37581]
# 100%|██████████| 8/8 [00:01<00:00,  6.07it/s]47s/it]
# Loss_D [-1.06399]; Loss_G [0.54339]; D_real [-0.57098]; Loss_D_fake [0.49301]
# 100%|██████████| 8/8 [00:01<00:00,  5.99it/s]47s/it]
# Loss_D [-0.96485]; Loss_G [0.49151]; D_real [-0.50225]; Loss_D_fake [0.4626]
# 100%|██████████| 8/8 [00:01<00:00,  5.38it/s]47s/it]
# Loss_D [-0.76776]; Loss_G [0.26759]; D_real [-0.2196]; Loss_D_fake [0.54816]
# 100%|██████████| 8/8 [00:01<00:00,  6.30it/s]47s/it]
# Loss_D [-1.06821]; Loss_G [0.55583]; D_real [-0.54446]; Loss_D_fake [0.52375]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s]47s/it]
# Loss_D [-1.05479]; Loss_G [0.59998]; D_real [-0.62683]; Loss_D_fake [0.42796]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]47s/it]
# Loss_D [-1.03986]; Loss_G [0.54757]; D_real [-0.56578]; Loss_D_fake [0.47407]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]47s/it]
# Loss_D [-0.90622]; Loss_G [0.61851]; D_real [-0.66362]; Loss_D_fake [0.24261]
# 100%|██████████| 8/8 [00:01<00:00,  6.35it/s]47s/it]
# Loss_D [-1.04661]; Loss_G [0.54987]; D_real [-0.5098]; Loss_D_fake [0.53681]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]47s/it]
# Loss_D [-0.83211]; Loss_G [0.5356]; D_real [-0.54443]; Loss_D_fake [0.28768]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]47s/it]
# Loss_D [-1.01007]; Loss_G [0.55835]; D_real [-0.56486]; Loss_D_fake [0.44521]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s]47s/it]
# Loss_D [-0.59102]; Loss_G [0.16204]; D_real [-0.09675]; Loss_D_fake [0.49427]
# 100%|██████████| 8/8 [00:01<00:00,  6.29it/s]47s/it]
# Loss_D [-0.83443]; Loss_G [0.20431]; D_real [-0.19584]; Loss_D_fake [0.63859]
# 100%|██████████| 8/8 [00:01<00:00,  6.37it/s]47s/it]
# Loss_D [-0.96877]; Loss_G [0.35976]; D_real [-0.37133]; Loss_D_fake [0.59744]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s]47s/it]
# Loss_D [-1.07643]; Loss_G [0.54056]; D_real [-0.54076]; Loss_D_fake [0.53568]
# 100%|██████████| 8/8 [00:01<00:00,  6.14it/s]47s/it]
# Loss_D [-0.95515]; Loss_G [0.32608]; D_real [-0.45958]; Loss_D_fake [0.49556]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s]47s/it]
# Loss_D [-0.88241]; Loss_G [0.17902]; D_real [-0.29224]; Loss_D_fake [0.59017]
# 100%|██████████| 8/8 [00:01<00:00,  6.31it/s]46s/it]
# Loss_D [-0.90923]; Loss_G [0.49188]; D_real [-0.40614]; Loss_D_fake [0.5031]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s]46s/it]
# Loss_D [-1.10662]; Loss_G [0.5923]; D_real [-0.60124]; Loss_D_fake [0.50538]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s]46s/it]
# Loss_D [-0.53931]; Loss_G [0.29203]; D_real [-0.25169]; Loss_D_fake [0.28762]
# 100%|██████████| 8/8 [00:01<00:00,  6.29it/s]47s/it]
# Loss_D [-0.93541]; Loss_G [0.36226]; D_real [-0.39643]; Loss_D_fake [0.53898]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]47s/it]
# Loss_D [-0.79073]; Loss_G [0.23835]; D_real [-0.25694]; Loss_D_fake [0.53379]
# 100%|██████████| 8/8 [00:01<00:00,  6.14it/s]47s/it]
# Loss_D [-1.13955]; Loss_G [0.48768]; D_real [-0.53815]; Loss_D_fake [0.6014]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]47s/it]
# Loss_D [-1.09683]; Loss_G [0.59499]; D_real [-0.5972]; Loss_D_fake [0.49963]
# 100%|██████████| 8/8 [00:02<00:00,  4.68it/s]47s/it]
# Loss_D [-1.09739]; Loss_G [0.60459]; D_real [-0.63273]; Loss_D_fake [0.46465]
# 100%|██████████| 8/8 [00:01<00:00,  6.29it/s]47s/it]
# Loss_D [-1.02547]; Loss_G [0.60785]; D_real [-0.62182]; Loss_D_fake [0.40364]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s]47s/it]
# Loss_D [-0.91777]; Loss_G [0.49038]; D_real [-0.39113]; Loss_D_fake [0.52664]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]47s/it]
# Loss_D [-1.13575]; Loss_G [0.5618]; D_real [-0.54006]; Loss_D_fake [0.59568]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s]47s/it]
# Loss_D [-0.88567]; Loss_G [0.17672]; D_real [-0.32995]; Loss_D_fake [0.55572]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s]47s/it]
# Loss_D [-0.78941]; Loss_G [0.17725]; D_real [-0.19682]; Loss_D_fake [0.59259]
# 100%|██████████| 8/8 [00:01<00:00,  6.10it/s]47s/it]
# Loss_D [-0.87164]; Loss_G [0.24972]; D_real [-0.26341]; Loss_D_fake [0.60824]
# 100%|██████████| 8/8 [00:02<00:00,  4.47it/s]47s/it]
# Loss_D [-0.75545]; Loss_G [0.16673]; D_real [-0.20972]; Loss_D_fake [0.54572]
# 100%|██████████| 8/8 [00:01<00:00,  6.30it/s]47s/it]
# Loss_D [-1.07695]; Loss_G [0.56894]; D_real [-0.52601]; Loss_D_fake [0.55094]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]47s/it]
# Loss_D [-1.0404]; Loss_G [0.45421]; D_real [-0.48862]; Loss_D_fake [0.55179]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s]47s/it]
# Loss_D [-0.96285]; Loss_G [0.2933]; D_real [-0.33661]; Loss_D_fake [0.62624]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]47s/it]
# Loss_D [-1.12268]; Loss_G [0.51687]; D_real [-0.53656]; Loss_D_fake [0.58612]
# 100%|██████████| 8/8 [00:01<00:00,  5.12it/s]47s/it]
# Loss_D [-1.1014]; Loss_G [0.50656]; D_real [-0.56174]; Loss_D_fake [0.53966]
# 100%|██████████| 8/8 [00:02<00:00,  3.80it/s]48s/it]
# Loss_D [-0.91228]; Loss_G [0.54979]; D_real [-0.5945]; Loss_D_fake [0.31778]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s]48s/it]
# Loss_D [-1.11683]; Loss_G [0.54664]; D_real [-0.60613]; Loss_D_fake [0.5107]
# 100%|██████████| 8/8 [00:01<00:00,  6.28it/s]48s/it]
# Loss_D [-0.75946]; Loss_G [0.53833]; D_real [-0.44498]; Loss_D_fake [0.31448]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s]48s/it]
# Loss_D [-1.15821]; Loss_G [0.54263]; D_real [-0.58677]; Loss_D_fake [0.57144]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]48s/it]
# Loss_D [-0.96445]; Loss_G [0.58416]; D_real [-0.64013]; Loss_D_fake [0.32432]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]48s/it]
# Loss_D [-0.8982]; Loss_G [0.55665]; D_real [-0.51591]; Loss_D_fake [0.38229]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s]48s/it]
# Loss_D [-1.04683]; Loss_G [0.58858]; D_real [-0.61833]; Loss_D_fake [0.4285]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]48s/it]
# Loss_D [-0.75423]; Loss_G [0.52192]; D_real [-0.45194]; Loss_D_fake [0.30229]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]48s/it]
# Loss_D [-1.00398]; Loss_G [0.40282]; D_real [-0.47181]; Loss_D_fake [0.53217]
# 100%|██████████| 8/8 [00:01<00:00,  5.85it/s]48s/it]
# Loss_D [-1.0112]; Loss_G [0.58299]; D_real [-0.61196]; Loss_D_fake [0.39925]
# 100%|██████████| 8/8 [00:01<00:00,  5.75it/s]48s/it]
# Loss_D [-0.90975]; Loss_G [0.52777]; D_real [-0.54965]; Loss_D_fake [0.3601]
# 100%|██████████| 8/8 [00:01<00:00,  5.75it/s]48s/it]
# Loss_D [-1.07293]; Loss_G [0.50431]; D_real [-0.47813]; Loss_D_fake [0.5948]
# 100%|██████████| 8/8 [00:01<00:00,  5.31it/s]48s/it]
# Loss_D [-0.98051]; Loss_G [0.55545]; D_real [-0.54686]; Loss_D_fake [0.43365]
# 100%|██████████| 8/8 [00:01<00:00,  5.30it/s]48s/it]
# Loss_D [-0.98693]; Loss_G [0.42477]; D_real [-0.44369]; Loss_D_fake [0.54324]
# 100%|██████████| 8/8 [00:01<00:00,  5.33it/s]48s/it]
# Loss_D [-0.95194]; Loss_G [0.31733]; D_real [-0.36976]; Loss_D_fake [0.58218]
# 100%|██████████| 8/8 [00:01<00:00,  5.31it/s]48s/it]
# Loss_D [-1.13542]; Loss_G [0.58011]; D_real [-0.55916]; Loss_D_fake [0.57626]
# 100%|██████████| 8/8 [00:01<00:00,  5.50it/s]49s/it]
# Loss_D [-0.86466]; Loss_G [0.52559]; D_real [-0.50325]; Loss_D_fake [0.36142]
# 100%|██████████| 8/8 [00:01<00:00,  5.77it/s]49s/it]
# Loss_D [-1.07]; Loss_G [0.51669]; D_real [-0.53113]; Loss_D_fake [0.53887]
# 100%|██████████| 8/8 [00:01<00:00,  5.74it/s]49s/it]
# Loss_D [-0.93058]; Loss_G [0.61379]; D_real [-0.55202]; Loss_D_fake [0.37857]
# 100%|██████████| 8/8 [00:01<00:00,  5.95it/s]49s/it]
# Loss_D [-0.91416]; Loss_G [0.59897]; D_real [-0.62882]; Loss_D_fake [0.28534]
# 100%|██████████| 8/8 [00:01<00:00,  5.95it/s]49s/it]
# Loss_D [-1.00304]; Loss_G [0.39864]; D_real [-0.46668]; Loss_D_fake [0.53636]
# 100%|██████████| 8/8 [00:01<00:00,  5.91it/s]49s/it]
# Loss_D [-1.09871]; Loss_G [0.54416]; D_real [-0.53649]; Loss_D_fake [0.56223]
# 100%|██████████| 8/8 [00:01<00:00,  5.79it/s]49s/it]
# Loss_D [-1.04427]; Loss_G [0.61437]; D_real [-0.59209]; Loss_D_fake [0.45218]
# 100%|██████████| 8/8 [00:01<00:00,  5.69it/s]49s/it]
# Loss_D [-1.06436]; Loss_G [0.48495]; D_real [-0.54051]; Loss_D_fake [0.52386]
# 100%|██████████| 8/8 [00:01<00:00,  5.40it/s]49s/it]
# Loss_D [-1.16142]; Loss_G [0.51217]; D_real [-0.54789]; Loss_D_fake [0.61352]
# 100%|██████████| 8/8 [00:01<00:00,  5.42it/s]49s/it]
# Loss_D [-0.94767]; Loss_G [0.38524]; D_real [-0.44208]; Loss_D_fake [0.50559]
# 100%|██████████| 8/8 [00:01<00:00,  5.36it/s]49s/it]
# Loss_D [-1.28844]; Loss_G [0.64288]; D_real [-0.65587]; Loss_D_fake [0.63257]
# 100%|██████████| 8/8 [00:01<00:00,  5.41it/s]49s/it]
# Loss_D [-0.92871]; Loss_G [0.45015]; D_real [-0.4598]; Loss_D_fake [0.46891]
# 100%|██████████| 8/8 [00:01<00:00,  5.42it/s]49s/it]
# Loss_D [-1.03377]; Loss_G [0.41612]; D_real [-0.43427]; Loss_D_fake [0.5995]
# 100%|██████████| 8/8 [00:01<00:00,  5.80it/s]50s/it]
# Loss_D [-1.11231]; Loss_G [0.54265]; D_real [-0.48845]; Loss_D_fake [0.62386]
# 100%|██████████| 8/8 [00:01<00:00,  5.82it/s]50s/it]
# Loss_D [-0.90813]; Loss_G [0.65044]; D_real [-0.64784]; Loss_D_fake [0.26029]
# 100%|██████████| 8/8 [00:01<00:00,  5.99it/s]50s/it]
# Loss_D [-1.09862]; Loss_G [0.54705]; D_real [-0.59533]; Loss_D_fake [0.50329]
# 100%|██████████| 8/8 [00:01<00:00,  6.06it/s]50s/it]
# Loss_D [-1.00973]; Loss_G [0.5737]; D_real [-0.54806]; Loss_D_fake [0.46167]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s]50s/it]
# Loss_D [-0.89068]; Loss_G [0.53149]; D_real [-0.47674]; Loss_D_fake [0.41394]
# 100%|██████████| 8/8 [00:01<00:00,  5.14it/s]50s/it]
# Loss_D [-1.0859]; Loss_G [0.53873]; D_real [-0.50767]; Loss_D_fake [0.57822]
# 100%|██████████| 8/8 [00:01<00:00,  5.33it/s]50s/it]
# Loss_D [-0.65897]; Loss_G [0.05432]; D_real [-0.218]; Loss_D_fake [0.44097]
# 100%|██████████| 8/8 [00:01<00:00,  6.01it/s]50s/it]
# Loss_D [-0.78616]; Loss_G [0.18088]; D_real [-0.16002]; Loss_D_fake [0.62615]
# 100%|██████████| 8/8 [00:01<00:00,  5.07it/s]50s/it]
# Loss_D [-1.19685]; Loss_G [0.58766]; D_real [-0.61552]; Loss_D_fake [0.58134]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]50s/it]
# Loss_D [-1.04641]; Loss_G [0.6092]; D_real [-0.59102]; Loss_D_fake [0.45539]
# 100%|██████████| 8/8 [00:01<00:00,  5.37it/s]50s/it]
# Loss_D [-0.99554]; Loss_G [0.53208]; D_real [-0.56313]; Loss_D_fake [0.43241]
# 100%|██████████| 8/8 [00:01<00:00,  5.36it/s]50s/it]
# Loss_D [-1.03369]; Loss_G [0.46132]; D_real [-0.44239]; Loss_D_fake [0.5913]
# 100%|██████████| 8/8 [00:01<00:00,  5.24it/s]50s/it]
# Loss_D [-0.91902]; Loss_G [0.38582]; D_real [-0.32664]; Loss_D_fake [0.59238]
# 100%|██████████| 8/8 [00:01<00:00,  5.23it/s]50s/it]
# Loss_D [-0.62366]; Loss_G [-0.07037]; D_real [-0.0233]; Loss_D_fake [0.60037]
# 100%|██████████| 8/8 [00:01<00:00,  5.67it/s]51s/it]
# Loss_D [-0.96932]; Loss_G [0.5538]; D_real [-0.44458]; Loss_D_fake [0.52475]
# 100%|██████████| 8/8 [00:01<00:00,  5.71it/s]51s/it]
# Loss_D [-0.73635]; Loss_G [0.52656]; D_real [-0.41753]; Loss_D_fake [0.31883]
# 100%|██████████| 8/8 [00:01<00:00,  5.76it/s]51s/it]
# Loss_D [-0.87346]; Loss_G [0.15904]; D_real [-0.38474]; Loss_D_fake [0.48873]
# 100%|██████████| 8/8 [00:01<00:00,  5.33it/s]51s/it]
# Loss_D [-0.77989]; Loss_G [-0.00096]; D_real [-0.11756]; Loss_D_fake [0.66232]
# 100%|██████████| 8/8 [00:01<00:00,  5.35it/s]51s/it]
# Loss_D [-0.99981]; Loss_G [0.44691]; D_real [-0.46594]; Loss_D_fake [0.53387]
# 100%|██████████| 8/8 [00:01<00:00,  5.26it/s]51s/it]
# Loss_D [-0.72128]; Loss_G [0.08038]; D_real [-0.23298]; Loss_D_fake [0.4883]
# 100%|██████████| 8/8 [00:01<00:00,  5.32it/s]51s/it]
# Loss_D [-0.9515]; Loss_G [0.58504]; D_real [-0.59394]; Loss_D_fake [0.35756]
# 100%|██████████| 8/8 [00:01<00:00,  5.59it/s]51s/it]
# Loss_D [-0.83262]; Loss_G [0.25973]; D_real [-0.33272]; Loss_D_fake [0.4999]
# 100%|██████████| 8/8 [00:01<00:00,  5.79it/s]51s/it]
# Loss_D [-0.85733]; Loss_G [0.15956]; D_real [-0.23983]; Loss_D_fake [0.61751]
# 100%|██████████| 8/8 [00:01<00:00,  5.76it/s]51s/it]
# Loss_D [-0.88547]; Loss_G [0.27579]; D_real [-0.28616]; Loss_D_fake [0.59931]
# 100%|██████████| 8/8 [00:01<00:00,  6.01it/s]51s/it]
# Loss_D [-0.95957]; Loss_G [0.49641]; D_real [-0.44738]; Loss_D_fake [0.51219]
# 100%|██████████| 8/8 [00:01<00:00,  6.09it/s]51s/it]
# Loss_D [-0.79209]; Loss_G [-0.06369]; D_real [-0.25849]; Loss_D_fake [0.5336]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s]51s/it]
# Loss_D [-0.9696]; Loss_G [0.42675]; D_real [-0.36251]; Loss_D_fake [0.60709]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s]51s/it]
# Loss_D [-0.96656]; Loss_G [0.49652]; D_real [-0.50272]; Loss_D_fake [0.46384]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s]51s/it]
# Loss_D [-1.01243]; Loss_G [0.37701]; D_real [-0.46411]; Loss_D_fake [0.54833]
# 100%|██████████| 8/8 [00:01<00:00,  4.72it/s]51s/it]
# Loss_D [-0.91476]; Loss_G [0.30807]; D_real [-0.27762]; Loss_D_fake [0.63714]
# 100%|██████████| 8/8 [00:01<00:00,  4.79it/s]51s/it]
# Loss_D [-0.86353]; Loss_G [0.28561]; D_real [-0.33475]; Loss_D_fake [0.52878]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]52s/it]
# Loss_D [-1.0886]; Loss_G [0.53255]; D_real [-0.50374]; Loss_D_fake [0.58486]
# 100%|██████████| 8/8 [00:01<00:00,  6.14it/s]52s/it]
# Loss_D [-0.73183]; Loss_G [-0.01806]; D_real [-0.22494]; Loss_D_fake [0.50689]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s]52s/it]
# Loss_D [-1.17113]; Loss_G [0.54554]; D_real [-0.61462]; Loss_D_fake [0.55651]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s]51s/it]
# Loss_D [-0.86986]; Loss_G [0.41597]; D_real [-0.41669]; Loss_D_fake [0.45317]
# 100%|██████████| 8/8 [00:01<00:00,  5.83it/s]51s/it]
# Loss_D [-1.12783]; Loss_G [0.59213]; D_real [-0.63389]; Loss_D_fake [0.49394]
# 100%|██████████| 8/8 [00:01<00:00,  5.75it/s]51s/it]
# Loss_D [-0.8307]; Loss_G [0.51661]; D_real [-0.49533]; Loss_D_fake [0.33537]
# 100%|██████████| 8/8 [00:01<00:00,  6.04it/s]51s/it]
# Loss_D [-0.94767]; Loss_G [0.39066]; D_real [-0.48647]; Loss_D_fake [0.4612]
# 100%|██████████| 8/8 [00:01<00:00,  6.10it/s]51s/it]
# Loss_D [-1.08083]; Loss_G [0.55122]; D_real [-0.56172]; Loss_D_fake [0.51911]
# 100%|██████████| 8/8 [00:01<00:00,  6.07it/s]51s/it]
# Loss_D [-0.83571]; Loss_G [0.58975]; D_real [-0.60747]; Loss_D_fake [0.22824]
# 100%|██████████| 8/8 [00:01<00:00,  5.83it/s]51s/it]
# Loss_D [-0.91624]; Loss_G [0.41136]; D_real [-0.46588]; Loss_D_fake [0.45035]
# 100%|██████████| 8/8 [00:01<00:00,  5.79it/s]51s/it]
# Loss_D [-1.00782]; Loss_G [0.46951]; D_real [-0.50465]; Loss_D_fake [0.50317]
# 100%|██████████| 8/8 [00:01<00:00,  5.96it/s]51s/it]
# Loss_D [-0.80496]; Loss_G [0.44435]; D_real [-0.43685]; Loss_D_fake [0.36811]
# 100%|██████████| 8/8 [00:01<00:00,  5.89it/s]51s/it]
# Loss_D [-1.0774]; Loss_G [0.59958]; D_real [-0.57026]; Loss_D_fake [0.50714]
# 100%|██████████| 8/8 [00:01<00:00,  5.93it/s]51s/it]
# Loss_D [-0.90186]; Loss_G [0.53825]; D_real [-0.61241]; Loss_D_fake [0.28946]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s]51s/it]
# Loss_D [-1.10666]; Loss_G [0.46689]; D_real [-0.49363]; Loss_D_fake [0.61304]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]51s/it]
# Loss_D [-0.96929]; Loss_G [0.6385]; D_real [-0.62895]; Loss_D_fake [0.34034]
# 100%|██████████| 8/8 [00:01<00:00,  6.06it/s]51s/it]
# Loss_D [-0.86491]; Loss_G [0.62345]; D_real [-0.61871]; Loss_D_fake [0.2462]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s]51s/it]
# Loss_D [-1.02375]; Loss_G [0.52988]; D_real [-0.57977]; Loss_D_fake [0.44397]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s]51s/it]
# Loss_D [-0.9337]; Loss_G [0.62158]; D_real [-0.63598]; Loss_D_fake [0.29772]
# 100%|██████████| 8/8 [00:01<00:00,  5.53it/s]51s/it]
# Loss_D [-0.76428]; Loss_G [0.47413]; D_real [-0.39781]; Loss_D_fake [0.36647]
# 100%|██████████| 8/8 [00:01<00:00,  5.35it/s]51s/it]
# Loss_D [-0.87532]; Loss_G [0.47777]; D_real [-0.45695]; Loss_D_fake [0.41838]
# 100%|██████████| 8/8 [00:01<00:00,  5.28it/s]52s/it]
# Loss_D [-0.86457]; Loss_G [0.55729]; D_real [-0.52958]; Loss_D_fake [0.33498]
# 100%|██████████| 8/8 [00:01<00:00,  5.28it/s]52s/it]
# Loss_D [-1.01015]; Loss_G [0.59246]; D_real [-0.60668]; Loss_D_fake [0.40348]
# 100%|██████████| 8/8 [00:01<00:00,  5.34it/s]52s/it]
# Loss_D [-1.10516]; Loss_G [0.52362]; D_real [-0.57555]; Loss_D_fake [0.5296]
# 100%|██████████| 8/8 [00:01<00:00,  5.77it/s]52s/it]
# Loss_D [-0.91884]; Loss_G [0.6421]; D_real [-0.64934]; Loss_D_fake [0.26951]
# 100%|██████████| 8/8 [00:01<00:00,  5.82it/s]52s/it]
# Loss_D [-0.87894]; Loss_G [0.53099]; D_real [-0.56302]; Loss_D_fake [0.31592]
# 100%|██████████| 8/8 [00:01<00:00,  5.45it/s]52s/it]
# Loss_D [-0.9368]; Loss_G [0.44847]; D_real [-0.46071]; Loss_D_fake [0.47609]
# 100%|██████████| 8/8 [00:01<00:00,  5.43it/s]52s/it]
# Loss_D [-0.75324]; Loss_G [0.34053]; D_real [-0.26963]; Loss_D_fake [0.48361]
# 100%|██████████| 8/8 [00:01<00:00,  5.44it/s]52s/it]
# Loss_D [-0.77509]; Loss_G [0.21868]; D_real [-0.16995]; Loss_D_fake [0.60515]
# 100%|██████████| 8/8 [00:01<00:00,  5.36it/s]52s/it]
# Loss_D [-1.15249]; Loss_G [0.55974]; D_real [-0.54533]; Loss_D_fake [0.60716]
# 100%|██████████| 8/8 [00:01<00:00,  5.39it/s]52s/it]
# Loss_D [-1.024]; Loss_G [0.61089]; D_real [-0.6882]; Loss_D_fake [0.33581]
# 100%|██████████| 8/8 [00:01<00:00,  5.84it/s]52s/it]
# Loss_D [-1.08406]; Loss_G [0.56819]; D_real [-0.55762]; Loss_D_fake [0.52644]
# 100%|██████████| 8/8 [00:01<00:00,  5.78it/s]52s/it]
# Loss_D [-0.75994]; Loss_G [0.46626]; D_real [-0.40224]; Loss_D_fake [0.35769]
# 100%|██████████| 8/8 [00:01<00:00,  5.86it/s]52s/it]
# Loss_D [-1.05455]; Loss_G [0.29272]; D_real [-0.45646]; Loss_D_fake [0.59809]
# 100%|██████████| 8/8 [00:01<00:00,  5.99it/s]52s/it]
# Loss_D [-1.16967]; Loss_G [0.52036]; D_real [-0.56912]; Loss_D_fake [0.60055]
# 100%|██████████| 8/8 [00:01<00:00,  6.07it/s]52s/it]
# Loss_D [-1.06606]; Loss_G [0.57506]; D_real [-0.60363]; Loss_D_fake [0.46243]
# 100%|██████████| 8/8 [00:01<00:00,  6.27it/s]52s/it]
# Loss_D [-0.8885]; Loss_G [0.60826]; D_real [-0.64182]; Loss_D_fake [0.24668]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]52s/it]
# Loss_D [-0.96449]; Loss_G [0.5833]; D_real [-0.5817]; Loss_D_fake [0.38279]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s]52s/it]
# Loss_D [-0.96815]; Loss_G [0.48475]; D_real [-0.47435]; Loss_D_fake [0.49379]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]52s/it]
# Loss_D [-1.11487]; Loss_G [0.53872]; D_real [-0.56028]; Loss_D_fake [0.55459]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s]52s/it]
# Loss_D [-0.83512]; Loss_G [0.64962]; D_real [-0.65839]; Loss_D_fake [0.17672]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s]52s/it]
# Loss_D [-1.01635]; Loss_G [0.44064]; D_real [-0.47553]; Loss_D_fake [0.54082]
# 100%|██████████| 8/8 [00:01<00:00,  6.09it/s]52s/it]
# Loss_D [-0.84844]; Loss_G [0.16876]; D_real [-0.29303]; Loss_D_fake [0.55541]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s]52s/it]
# Loss_D [-0.96825]; Loss_G [0.44086]; D_real [-0.40465]; Loss_D_fake [0.5636]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s]52s/it]
# Loss_D [-0.88732]; Loss_G [0.14042]; D_real [-0.28747]; Loss_D_fake [0.59986]
# 100%|██████████| 8/8 [00:01<00:00,  5.89it/s]52s/it]
# Loss_D [-0.84471]; Loss_G [0.10591]; D_real [-0.24154]; Loss_D_fake [0.60318]
# 100%|██████████| 8/8 [00:01<00:00,  5.78it/s]52s/it]
# Loss_D [-0.69977]; Loss_G [0.2189]; D_real [-0.08868]; Loss_D_fake [0.61109]
# 100%|██████████| 8/8 [00:01<00:00,  5.39it/s]52s/it]
# Loss_D [-0.90579]; Loss_G [0.41091]; D_real [-0.36472]; Loss_D_fake [0.54107]
# 100%|██████████| 8/8 [00:01<00:00,  5.41it/s]52s/it]
# Loss_D [-1.04003]; Loss_G [0.48486]; D_real [-0.45805]; Loss_D_fake [0.58198]
# 100%|██████████| 8/8 [00:01<00:00,  5.40it/s]52s/it]
# Loss_D [-0.95689]; Loss_G [0.49527]; D_real [-0.44263]; Loss_D_fake [0.51425]
# 100%|██████████| 8/8 [00:01<00:00,  5.41it/s]52s/it]
# Loss_D [-0.95765]; Loss_G [0.62583]; D_real [-0.5875]; Loss_D_fake [0.37015]
# 100%|██████████| 8/8 [00:01<00:00,  5.39it/s]52s/it]
# Loss_D [-0.81159]; Loss_G [0.54088]; D_real [-0.56303]; Loss_D_fake [0.24856]
# 100%|██████████| 8/8 [00:01<00:00,  5.81it/s]52s/it]
# Loss_D [-0.93854]; Loss_G [0.5637]; D_real [-0.57379]; Loss_D_fake [0.36474]
# 100%|██████████| 8/8 [00:01<00:00,  5.80it/s]52s/it]
# Loss_D [-0.91073]; Loss_G [0.49183]; D_real [-0.49905]; Loss_D_fake [0.41168]
# 100%|██████████| 8/8 [00:01<00:00,  5.95it/s]52s/it]
# Loss_D [-0.8652]; Loss_G [0.59062]; D_real [-0.58164]; Loss_D_fake [0.28356]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s]52s/it]
# Loss_D [-0.91377]; Loss_G [0.49152]; D_real [-0.54868]; Loss_D_fake [0.36509]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s]52s/it]
# Loss_D [-0.92594]; Loss_G [0.57285]; D_real [-0.56202]; Loss_D_fake [0.36392]
# 100%|██████████| 8/8 [00:01<00:00,  5.76it/s]52s/it]
# Loss_D [-0.95998]; Loss_G [0.54247]; D_real [-0.55847]; Loss_D_fake [0.4015]
# 100%|██████████| 8/8 [00:01<00:00,  5.77it/s]52s/it]
# Loss_D [-0.94008]; Loss_G [0.64436]; D_real [-0.65143]; Loss_D_fake [0.28865]
# 100%|██████████| 8/8 [00:01<00:00,  5.75it/s]52s/it]
# Loss_D [-1.0693]; Loss_G [0.46298]; D_real [-0.52955]; Loss_D_fake [0.53975]
# 100%|██████████| 8/8 [00:02<00:00,  4.32it/s]52s/it]
# Loss_D [-0.98846]; Loss_G [0.51633]; D_real [-0.56374]; Loss_D_fake [0.42472]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s]53s/it]
# Loss_D [-0.9368]; Loss_G [0.5617]; D_real [-0.63133]; Loss_D_fake [0.30547]
# 100%|██████████| 8/8 [00:01<00:00,  6.32it/s]53s/it]
# Loss_D [-0.98467]; Loss_G [0.56829]; D_real [-0.58128]; Loss_D_fake [0.40339]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]53s/it]
# Loss_D [-0.89299]; Loss_G [0.37395]; D_real [-0.39791]; Loss_D_fake [0.49508]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s]53s/it]
# Loss_D [-1.11078]; Loss_G [0.51929]; D_real [-0.52565]; Loss_D_fake [0.58513]
# 100%|██████████| 8/8 [00:01<00:00,  6.14it/s]53s/it]
# Loss_D [-0.71168]; Loss_G [0.07002]; D_real [-0.23064]; Loss_D_fake [0.48104]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s]53s/it]
# Loss_D [-1.02671]; Loss_G [0.32516]; D_real [-0.41246]; Loss_D_fake [0.61425]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s]52s/it]
# Loss_D [-0.94035]; Loss_G [0.41799]; D_real [-0.4549]; Loss_D_fake [0.48546]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]52s/it]
# Loss_D [-1.04526]; Loss_G [0.54864]; D_real [-0.46738]; Loss_D_fake [0.57788]
# 100%|██████████| 8/8 [00:01<00:00,  6.18it/s]52s/it]
# Loss_D [-0.81577]; Loss_G [0.60151]; D_real [-0.6368]; Loss_D_fake [0.17898]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s]52s/it]
# Loss_D [-0.85649]; Loss_G [0.37609]; D_real [-0.30271]; Loss_D_fake [0.55378]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]52s/it]
# Loss_D [-0.9108]; Loss_G [0.43497]; D_real [-0.30635]; Loss_D_fake [0.60445]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]52s/it]
# Loss_D [-1.03702]; Loss_G [0.49459]; D_real [-0.47521]; Loss_D_fake [0.56181]
# 100%|██████████| 8/8 [00:01<00:00,  4.88it/s]52s/it]
# Loss_D [-0.82351]; Loss_G [0.27042]; D_real [-0.38538]; Loss_D_fake [0.43813]
# 100%|██████████| 8/8 [00:01<00:00,  4.99it/s]52s/it]
# Loss_D [-1.14984]; Loss_G [0.52999]; D_real [-0.52413]; Loss_D_fake [0.6257]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s]53s/it]
# Loss_D [-0.82798]; Loss_G [0.25231]; D_real [-0.22829]; Loss_D_fake [0.59968]
# 100%|██████████| 8/8 [00:01<00:00,  5.79it/s]53s/it]
# Loss_D [-0.99252]; Loss_G [0.42259]; D_real [-0.38559]; Loss_D_fake [0.60694]
# 100%|██████████| 8/8 [00:01<00:00,  5.75it/s]53s/it]
# Loss_D [-1.30586]; Loss_G [0.63608]; D_real [-0.67257]; Loss_D_fake [0.63329]
# 100%|██████████| 8/8 [00:01<00:00,  4.96it/s]53s/it]
# Loss_D [-0.94673]; Loss_G [0.55189]; D_real [-0.56624]; Loss_D_fake [0.38049]
# 100%|██████████| 8/8 [00:01<00:00,  6.25it/s]53s/it]
# Loss_D [-1.01457]; Loss_G [0.46614]; D_real [-0.48326]; Loss_D_fake [0.53131]
# 100%|██████████| 8/8 [00:01<00:00,  6.08it/s]53s/it]
# Loss_D [-1.09278]; Loss_G [0.4938]; D_real [-0.51387]; Loss_D_fake [0.57891]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]53s/it]
# Loss_D [-1.00231]; Loss_G [0.28371]; D_real [-0.41022]; Loss_D_fake [0.59209]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s]53s/it]
# Loss_D [-0.53712]; Loss_G [0.14384]; D_real [0.07345]; Loss_D_fake [0.61058]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]53s/it]
# Loss_D [-0.85638]; Loss_G [0.10596]; D_real [-0.28782]; Loss_D_fake [0.56856]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s]53s/it]
# Loss_D [-1.01203]; Loss_G [0.4606]; D_real [-0.42872]; Loss_D_fake [0.58331]
# 100%|██████████| 8/8 [00:01<00:00,  6.14it/s]53s/it]
# Loss_D [-1.03335]; Loss_G [0.52897]; D_real [-0.55572]; Loss_D_fake [0.47763]
# 100%|██████████| 8/8 [00:01<00:00,  6.16it/s]53s/it]
# Loss_D [-0.86847]; Loss_G [0.40668]; D_real [-0.4337]; Loss_D_fake [0.43478]
# 100%|██████████| 8/8 [00:01<00:00,  6.13it/s]53s/it]
# Loss_D [-0.91486]; Loss_G [0.42207]; D_real [-0.41716]; Loss_D_fake [0.4977]
# 100%|██████████| 8/8 [00:01<00:00,  6.05it/s]52s/it]
# Loss_D [-1.21962]; Loss_G [0.60421]; D_real [-0.5953]; Loss_D_fake [0.62433]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s]52s/it]
# Loss_D [-1.066]; Loss_G [0.53161]; D_real [-0.61088]; Loss_D_fake [0.45512]
# 100%|██████████| 8/8 [00:01<00:00,  6.10it/s]52s/it]
# Loss_D [-1.14967]; Loss_G [0.59868]; D_real [-0.66253]; Loss_D_fake [0.48715]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]52s/it]
# Loss_D [-0.95984]; Loss_G [0.60733]; D_real [-0.58711]; Loss_D_fake [0.37273]
# 100%|██████████| 8/8 [00:01<00:00,  6.13it/s]52s/it]
# Loss_D [-1.01642]; Loss_G [0.54082]; D_real [-0.52423]; Loss_D_fake [0.49219]
# 100%|██████████| 8/8 [00:01<00:00,  6.10it/s]52s/it]
# Loss_D [-0.90901]; Loss_G [0.51826]; D_real [-0.46983]; Loss_D_fake [0.43918]
# 100%|██████████| 8/8 [00:01<00:00,  5.73it/s]52s/it]
# Loss_D [-1.02134]; Loss_G [0.58195]; D_real [-0.62408]; Loss_D_fake [0.39726]
# 100%|██████████| 8/8 [00:02<00:00,  4.36it/s]52s/it]
# Loss_D [-0.93217]; Loss_G [0.62183]; D_real [-0.62227]; Loss_D_fake [0.3099]
# 100%|██████████| 8/8 [00:02<00:00,  4.31it/s]53s/it]
# Loss_D [-0.98853]; Loss_G [0.51218]; D_real [-0.56054]; Loss_D_fake [0.42799]
# 100%|██████████| 8/8 [00:01<00:00,  6.23it/s]53s/it]
# Loss_D [-1.02527]; Loss_G [0.62042]; D_real [-0.64323]; Loss_D_fake [0.38205]
# 100%|██████████| 8/8 [00:01<00:00,  6.12it/s]53s/it]
# Loss_D [-0.95791]; Loss_G [0.56391]; D_real [-0.53336]; Loss_D_fake [0.42455]
# 100%|██████████| 8/8 [00:01<00:00,  6.09it/s]53s/it]
# Loss_D [-0.96757]; Loss_G [0.53795]; D_real [-0.53778]; Loss_D_fake [0.4298]
# 100%|██████████| 8/8 [00:01<00:00,  6.09it/s]53s/it]
# Loss_D [-0.94313]; Loss_G [0.63205]; D_real [-0.66685]; Loss_D_fake [0.27628]
# 100%|██████████| 8/8 [00:01<00:00,  6.04it/s]53s/it]
# Loss_D [-0.94604]; Loss_G [0.46025]; D_real [-0.48518]; Loss_D_fake [0.46086]
# 100%|██████████| 8/8 [00:01<00:00,  5.81it/s]53s/it]
# Loss_D [-1.07139]; Loss_G [0.62026]; D_real [-0.58635]; Loss_D_fake [0.48504]
# 100%|██████████| 8/8 [00:01<00:00,  5.83it/s]53s/it]
# Loss_D [-1.05045]; Loss_G [0.55624]; D_real [-0.62806]; Loss_D_fake [0.42239]
# 100%|██████████| 8/8 [00:01<00:00,  6.10it/s]53s/it]
# Loss_D [-1.06756]; Loss_G [0.56189]; D_real [-0.59745]; Loss_D_fake [0.47011]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s]53s/it]
# Loss_D [-1.1134]; Loss_G [0.5807]; D_real [-0.59622]; Loss_D_fake [0.51718]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]53s/it]
# Loss_D [-1.01563]; Loss_G [0.55793]; D_real [-0.5857]; Loss_D_fake [0.42993]
# 100%|██████████| 8/8 [00:01<00:00,  6.08it/s]53s/it]
# Loss_D [-0.97285]; Loss_G [0.58634]; D_real [-0.60782]; Loss_D_fake [0.36502]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s]53s/it]
# Loss_D [-0.96821]; Loss_G [0.64088]; D_real [-0.62327]; Loss_D_fake [0.34494]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s]53s/it]
# Loss_D [-0.76252]; Loss_G [0.40922]; D_real [-0.42151]; Loss_D_fake [0.34101]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s]53s/it]
# Loss_D [-1.0473]; Loss_G [0.55881]; D_real [-0.53863]; Loss_D_fake [0.50867]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]53s/it]
# Loss_D [-0.97736]; Loss_G [0.3657]; D_real [-0.4647]; Loss_D_fake [0.51266]
# 100%|██████████| 8/8 [00:01<00:00,  6.26it/s]53s/it]
# Loss_D [-1.0859]; Loss_G [0.55711]; D_real [-0.47831]; Loss_D_fake [0.60759]
# 100%|██████████| 8/8 [00:01<00:00,  6.20it/s]53s/it]
# Loss_D [-0.96577]; Loss_G [0.599]; D_real [-0.57716]; Loss_D_fake [0.38861]
# 100%|██████████| 8/8 [00:02<00:00,  4.71it/s]53s/it]
# Loss_D [-0.89894]; Loss_G [0.61498]; D_real [-0.5804]; Loss_D_fake [0.31854]
# 100%|██████████| 8/8 [00:01<00:00,  5.31it/s]53s/it]
# Loss_D [-0.59776]; Loss_G [0.30993]; D_real [-0.22064]; Loss_D_fake [0.37712]
# 100%|██████████| 8/8 [00:01<00:00,  6.15it/s]53s/it]
# Loss_D [-1.11401]; Loss_G [0.50258]; D_real [-0.52595]; Loss_D_fake [0.58806]
# 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]53s/it]
# Loss_D [-1.06052]; Loss_G [0.63031]; D_real [-0.66398]; Loss_D_fake [0.39654]
# 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]53s/it]
# Loss_D [-1.0544]; Loss_G [0.62438]; D_real [-0.63139]; Loss_D_fake [0.42301]
# 100%|██████████| 8/8 [00:01<00:00,  5.17it/s]53s/it]
# Loss_D [-0.62608]; Loss_G [0.30661]; D_real [-0.2466]; Loss_D_fake [0.37948]
# 100%|██████████| 8/8 [00:01<00:00,  5.78it/s]53s/it]
# Loss_D [-0.99731]; Loss_G [0.46246]; D_real [-0.42612]; Loss_D_fake [0.57119]
# 100%|██████████| 8/8 [00:01<00:00,  6.13it/s]53s/it]
# Loss_D [-1.08492]; Loss_G [0.48932]; D_real [-0.52286]; Loss_D_fake [0.56206]
# 100%|██████████| 8/8 [00:01<00:00,  6.24it/s]53s/it]
# Loss_D [-0.94858]; Loss_G [0.48929]; D_real [-0.4139]; Loss_D_fake [0.53468]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s]53s/it]
# Loss_D [-0.68855]; Loss_G [-0.10111]; D_real [-0.02578]; Loss_D_fake [0.66276]
# 100%|██████████| 8/8 [00:01<00:00,  6.19it/s]53s/it]
# Loss_D [-0.33379]; Loss_G [0.2806]; D_real [0.27376]; Loss_D_fake [0.60755]
# 100%|██████████| 8/8 [00:01<00:00,  6.17it/s]53s/it]
# Loss_D [-1.07127]; Loss_G [0.50252]; D_real [-0.45346]; Loss_D_fake [0.61781]
# 100%|██████████| 8/8 [00:01<00:00,  6.14it/s]53s/it]
# Loss_D [-1.09221]; Loss_G [0.44872]; D_real [-0.50745]; Loss_D_fake [0.58477]
# 100%|██████████| 8/8 [00:01<00:00,  6.22it/s]53s/it]
# Loss_D [-0.95314]; Loss_G [0.37962]; D_real [-0.35983]; Loss_D_fake [0.59331]
# 100%|██████████| 8/8 [00:01<00:00,  5.70it/s]53s/it]
# Loss_D [-1.1103]; Loss_G [0.52647]; D_real [-0.51611]; Loss_D_fake [0.59419]
# 100%|██████████| 8/8 [00:01<00:00,  5.72it/s]53s/it]
# Loss_D [-1.1298]; Loss_G [0.59337]; D_real [-0.6443]; Loss_D_fake [0.4855]
# 100%|██████████| 8/8 [00:01<00:00,  5.29it/s]53s/it]
# Loss_D [-1.03813]; Loss_G [0.57233]; D_real [-0.64398]; Loss_D_fake [0.39415]
# 100%|██████████| 8/8 [00:01<00:00,  5.23it/s]53s/it]
# Loss_D [-0.9374]; Loss_G [0.65334]; D_real [-0.63467]; Loss_D_fake [0.30274]
# 100%|██████████| 8/8 [00:01<00:00,  5.32it/s]53s/it]
# Loss_D [-0.97653]; Loss_G [0.49177]; D_real [-0.5615]; Loss_D_fake [0.41504]
# 100%|██████████| 8/8 [00:01<00:00,  5.37it/s]53s/it]
# Loss_D [-0.66066]; Loss_G [0.25166]; D_real [-0.3708]; Loss_D_fake [0.28985]
# 100%|██████████| 8/8 [00:01<00:00,  5.33it/s]53s/it]
# Loss_D [-1.17584]; Loss_G [0.55339]; D_real [-0.59841]; Loss_D_fake [0.57743]
# 100%|██████████| 8/8 [00:01<00:00,  5.69it/s]53s/it]
# Loss_D [-0.93243]; Loss_G [0.59098]; D_real [-0.59773]; Loss_D_fake [0.3347]
# 100%|██████████| 8/8 [00:01<00:00,  5.73it/s]53s/it]
# Loss_D [-0.91127]; Loss_G [0.52483]; D_real [-0.56929]; Loss_D_fake [0.34198]
# 100%|██████████| 8/8 [00:01<00:00,  5.50it/s]53s/it]
# Loss_D [-0.98791]; Loss_G [0.44114]; D_real [-0.51032]; Loss_D_fake [0.47759]
# 100%|██████████| 8/8 [00:01<00:00,  5.54it/s]53s/it]
# Loss_D [-1.05397]; Loss_G [0.38042]; D_real [-0.47862]; Loss_D_fake [0.57535]
# 100%|██████████| 8/8 [00:01<00:00,  5.57it/s]53s/it]
# Loss_D [-0.77331]; Loss_G [-0.0959]; D_real [-0.16536]; Loss_D_fake [0.60794]
# ...
# 100%|██████████| 8/8 [00:02<00:00,  4.36it/s].05s/it]
# Loss_D [-1.14631]; Loss_G [0.45404]; D_real [-0.51897]; Loss_D_fake [0.62735]
# 100%|██████████| 8/8 [00:02<00:00,  4.47it/s].05s/it]
# Loss_D [-1.09659]; Loss_G [0.48159]; D_real [-0.54818]; Loss_D_fake [0.54841]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].05s/it]
# Loss_D [-0.94931]; Loss_G [-0.01166]; D_real [-0.39794]; Loss_D_fake [0.55137]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].05s/it]
# Loss_D [-0.91253]; Loss_G [0.32982]; D_real [-0.26644]; Loss_D_fake [0.64609]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].05s/it]
# Loss_D [-1.14521]; Loss_G [0.40221]; D_real [-0.50185]; Loss_D_fake [0.64336]
# 100%|██████████| 8/8 [00:02<00:00,  4.44it/s].05s/it]
# Loss_D [-0.98701]; Loss_G [0.4896]; D_real [-0.44035]; Loss_D_fake [0.54666]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].05s/it]
# Loss_D [-1.11749]; Loss_G [0.47237]; D_real [-0.49261]; Loss_D_fake [0.62488]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].05s/it]
# Loss_D [-0.89209]; Loss_G [0.57836]; D_real [-0.52064]; Loss_D_fake [0.37145]
# 100%|██████████| 8/8 [00:02<00:00,  4.38it/s].05s/it]
# Loss_D [-1.1026]; Loss_G [0.56255]; D_real [-0.59974]; Loss_D_fake [0.50286]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].05s/it]
# Loss_D [-1.04688]; Loss_G [0.55985]; D_real [-0.64858]; Loss_D_fake [0.3983]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].05s/it]
# Loss_D [-1.0303]; Loss_G [0.51579]; D_real [-0.52695]; Loss_D_fake [0.50335]
# 100%|██████████| 8/8 [00:02<00:00,  4.47it/s].05s/it]
# Loss_D [-0.95797]; Loss_G [0.5334]; D_real [-0.52863]; Loss_D_fake [0.42934]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].05s/it]
# Loss_D [-1.01331]; Loss_G [0.64882]; D_real [-0.71988]; Loss_D_fake [0.29343]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].05s/it]
# Loss_D [-1.1733]; Loss_G [0.59014]; D_real [-0.65324]; Loss_D_fake [0.52006]
# 100%|██████████| 8/8 [00:02<00:00,  4.31it/s].06s/it]
# Loss_D [-1.19784]; Loss_G [0.52312]; D_real [-0.56843]; Loss_D_fake [0.62941]
# 100%|██████████| 8/8 [00:02<00:00,  4.50it/s].06s/it]
# Loss_D [-1.10189]; Loss_G [0.45275]; D_real [-0.54482]; Loss_D_fake [0.55707]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-0.7298]; Loss_G [-0.14091]; D_real [-0.08898]; Loss_D_fake [0.64082]
# 100%|██████████| 8/8 [00:02<00:00,  4.37it/s].06s/it]
# Loss_D [-1.07285]; Loss_G [0.48412]; D_real [-0.43392]; Loss_D_fake [0.63892]
# 100%|██████████| 8/8 [00:02<00:00,  4.52it/s].06s/it]
# Loss_D [-0.9642]; Loss_G [0.32389]; D_real [-0.31527]; Loss_D_fake [0.64893]
# 100%|██████████| 8/8 [00:02<00:00,  4.50it/s].06s/it]
# Loss_D [-1.26893]; Loss_G [0.57524]; D_real [-0.66146]; Loss_D_fake [0.60747]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-1.15049]; Loss_G [0.59251]; D_real [-0.67225]; Loss_D_fake [0.47824]
# 100%|██████████| 8/8 [00:02<00:00,  4.44it/s].06s/it]
# Loss_D [-0.86628]; Loss_G [-0.2557]; D_real [-0.27148]; Loss_D_fake [0.5948]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-1.02649]; Loss_G [0.58166]; D_real [-0.67064]; Loss_D_fake [0.35585]
# 100%|██████████| 8/8 [00:02<00:00,  4.44it/s].06s/it]
# Loss_D [-1.0024]; Loss_G [0.45273]; D_real [-0.48235]; Loss_D_fake [0.52005]
# 100%|██████████| 8/8 [00:02<00:00,  4.42it/s].06s/it]
# Loss_D [-1.01268]; Loss_G [0.49512]; D_real [-0.3519]; Loss_D_fake [0.66078]
# 100%|██████████| 8/8 [00:02<00:00,  4.36it/s].06s/it]
# Loss_D [-1.19064]; Loss_G [0.614]; D_real [-0.62608]; Loss_D_fake [0.56455]
# 100%|██████████| 8/8 [00:02<00:00,  4.51it/s].06s/it]
# Loss_D [-1.02089]; Loss_G [0.62371]; D_real [-0.67641]; Loss_D_fake [0.34447]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-1.09467]; Loss_G [0.54325]; D_real [-0.56187]; Loss_D_fake [0.5328]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-1.17642]; Loss_G [0.54585]; D_real [-0.54958]; Loss_D_fake [0.62684]
# 100%|██████████| 8/8 [00:02<00:00,  3.88it/s].06s/it]
# Loss_D [-1.16903]; Loss_G [0.62284]; D_real [-0.68052]; Loss_D_fake [0.48852]
# 100%|██████████| 8/8 [00:02<00:00,  4.32it/s].06s/it]
# Loss_D [-1.07311]; Loss_G [0.53775]; D_real [-0.62725]; Loss_D_fake [0.44587]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-1.23037]; Loss_G [0.56165]; D_real [-0.61056]; Loss_D_fake [0.6198]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-0.98905]; Loss_G [0.40135]; D_real [-0.48144]; Loss_D_fake [0.50762]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-0.90093]; Loss_G [0.01924]; D_real [-0.24565]; Loss_D_fake [0.65529]
# 100%|██████████| 8/8 [00:02<00:00,  4.42it/s].06s/it]
# Loss_D [-1.08992]; Loss_G [0.5285]; D_real [-0.49595]; Loss_D_fake [0.59397]
# 100%|██████████| 8/8 [00:02<00:00,  4.47it/s].06s/it]
# Loss_D [-1.03222]; Loss_G [0.47223]; D_real [-0.44484]; Loss_D_fake [0.58738]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-1.13117]; Loss_G [0.34086]; D_real [-0.46331]; Loss_D_fake [0.66786]
# 100%|██████████| 8/8 [00:02<00:00,  4.51it/s].06s/it]
# Loss_D [-0.9553]; Loss_G [0.11609]; D_real [-0.31723]; Loss_D_fake [0.63808]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-1.14018]; Loss_G [0.62912]; D_real [-0.67627]; Loss_D_fake [0.46391]
# 100%|██████████| 8/8 [00:02<00:00,  4.51it/s].06s/it]
# Loss_D [-0.89895]; Loss_G [0.58752]; D_real [-0.61646]; Loss_D_fake [0.28248]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-1.15187]; Loss_G [0.53172]; D_real [-0.57159]; Loss_D_fake [0.58028]
# 100%|██████████| 8/8 [00:02<00:00,  4.38it/s].06s/it]
# Loss_D [-1.24541]; Loss_G [0.6043]; D_real [-0.60103]; Loss_D_fake [0.64438]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-1.11399]; Loss_G [0.51012]; D_real [-0.54128]; Loss_D_fake [0.5727]
# 100%|██████████| 8/8 [00:02<00:00,  4.41it/s].06s/it]
# Loss_D [-1.05757]; Loss_G [0.55691]; D_real [-0.51732]; Loss_D_fake [0.54025]
# 100%|██████████| 8/8 [00:02<00:00,  4.44it/s].06s/it]
# Loss_D [-1.10806]; Loss_G [0.54044]; D_real [-0.53239]; Loss_D_fake [0.57567]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-1.21872]; Loss_G [0.59399]; D_real [-0.64887]; Loss_D_fake [0.56985]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-0.96416]; Loss_G [0.54037]; D_real [-0.56511]; Loss_D_fake [0.39905]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].06s/it]
# Loss_D [-1.25662]; Loss_G [0.56333]; D_real [-0.66355]; Loss_D_fake [0.59306]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-1.23092]; Loss_G [0.60241]; D_real [-0.66507]; Loss_D_fake [0.56585]
# 100%|██████████| 8/8 [00:02<00:00,  4.41it/s].06s/it]
# Loss_D [-1.1306]; Loss_G [0.60959]; D_real [-0.69032]; Loss_D_fake [0.44028]
# 100%|██████████| 8/8 [00:02<00:00,  4.44it/s].06s/it]
# Loss_D [-1.06796]; Loss_G [0.2735]; D_real [-0.42817]; Loss_D_fake [0.63979]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].06s/it]
# Loss_D [-1.016]; Loss_G [0.24005]; D_real [-0.3899]; Loss_D_fake [0.6261]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-0.69291]; Loss_G [0.00633]; D_real [-0.0483]; Loss_D_fake [0.64461]
# 100%|██████████| 8/8 [00:02<00:00,  3.87it/s].06s/it]
# Loss_D [-1.04873]; Loss_G [0.40169]; D_real [-0.45996]; Loss_D_fake [0.58877]
# 100%|██████████| 8/8 [00:02<00:00,  4.39it/s].06s/it]
# Loss_D [-1.081]; Loss_G [0.29749]; D_real [-0.48513]; Loss_D_fake [0.59587]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-0.91939]; Loss_G [0.32311]; D_real [-0.25406]; Loss_D_fake [0.66532]
# 100%|██████████| 8/8 [00:02<00:00,  4.54it/s].06s/it]
# Loss_D [-1.03664]; Loss_G [0.28619]; D_real [-0.44436]; Loss_D_fake [0.59228]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-1.25754]; Loss_G [0.55963]; D_real [-0.6485]; Loss_D_fake [0.60904]
# 100%|██████████| 8/8 [00:02<00:00,  4.50it/s].06s/it]
# Loss_D [-1.1028]; Loss_G [0.33476]; D_real [-0.49256]; Loss_D_fake [0.61023]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-1.2011]; Loss_G [0.5741]; D_real [-0.63321]; Loss_D_fake [0.56789]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].06s/it]
# Loss_D [-1.22857]; Loss_G [0.61342]; D_real [-0.67863]; Loss_D_fake [0.54994]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-0.86502]; Loss_G [0.06788]; D_real [-0.33278]; Loss_D_fake [0.53224]
# 100%|██████████| 8/8 [00:02<00:00,  4.42it/s].06s/it]
# Loss_D [-0.91226]; Loss_G [0.16004]; D_real [-0.28484]; Loss_D_fake [0.62743]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-1.06877]; Loss_G [0.516]; D_real [-0.46316]; Loss_D_fake [0.60561]
# 100%|██████████| 8/8 [00:02<00:00,  4.50it/s].06s/it]
# Loss_D [-1.13781]; Loss_G [0.61013]; D_real [-0.647]; Loss_D_fake [0.49081]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-1.09158]; Loss_G [0.57568]; D_real [-0.59121]; Loss_D_fake [0.50037]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-0.92138]; Loss_G [0.64864]; D_real [-0.65172]; Loss_D_fake [0.26965]
# 100%|██████████| 8/8 [00:02<00:00,  4.37it/s].06s/it]
# Loss_D [-1.08496]; Loss_G [0.46647]; D_real [-0.53632]; Loss_D_fake [0.54864]
# 100%|██████████| 8/8 [00:02<00:00,  4.26it/s].06s/it]
# Loss_D [-1.00062]; Loss_G [0.3331]; D_real [-0.3844]; Loss_D_fake [0.61622]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-1.20268]; Loss_G [0.58273]; D_real [-0.61986]; Loss_D_fake [0.58281]
# 100%|██████████| 8/8 [00:02<00:00,  4.37it/s].06s/it]
# Loss_D [-1.14441]; Loss_G [0.54544]; D_real [-0.56933]; Loss_D_fake [0.57508]
# 100%|██████████| 8/8 [00:02<00:00,  4.44it/s].06s/it]
# Loss_D [-1.20492]; Loss_G [0.56152]; D_real [-0.63146]; Loss_D_fake [0.57346]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-1.06487]; Loss_G [0.58748]; D_real [-0.66514]; Loss_D_fake [0.39972]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-0.93046]; Loss_G [0.64289]; D_real [-0.68885]; Loss_D_fake [0.2416]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-1.12354]; Loss_G [0.59656]; D_real [-0.61098]; Loss_D_fake [0.51256]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-1.20187]; Loss_G [0.61061]; D_real [-0.69076]; Loss_D_fake [0.51111]
# 100%|██████████| 8/8 [00:02<00:00,  4.53it/s].06s/it]
# Loss_D [-1.12682]; Loss_G [0.55492]; D_real [-0.61262]; Loss_D_fake [0.5142]
# 100%|██████████| 8/8 [00:02<00:00,  4.51it/s].06s/it]
# Loss_D [-1.14254]; Loss_G [0.62465]; D_real [-0.62728]; Loss_D_fake [0.51525]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-1.14639]; Loss_G [0.59465]; D_real [-0.66148]; Loss_D_fake [0.4849]
# 100%|██████████| 8/8 [00:02<00:00,  4.38it/s].06s/it]
# Loss_D [-0.85957]; Loss_G [0.07426]; D_real [-0.28807]; Loss_D_fake [0.5715]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-1.21776]; Loss_G [0.53944]; D_real [-0.56062]; Loss_D_fake [0.65713]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].06s/it]
# Loss_D [-1.17114]; Loss_G [0.5878]; D_real [-0.67756]; Loss_D_fake [0.49359]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-0.98223]; Loss_G [0.59939]; D_real [-0.64011]; Loss_D_fake [0.34213]
# 100%|██████████| 8/8 [00:02<00:00,  4.41it/s].06s/it]
# Loss_D [-1.13332]; Loss_G [0.51314]; D_real [-0.55897]; Loss_D_fake [0.57435]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-1.11683]; Loss_G [0.47113]; D_real [-0.47176]; Loss_D_fake [0.64507]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-1.10268]; Loss_G [0.45967]; D_real [-0.53055]; Loss_D_fake [0.57214]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-0.99923]; Loss_G [0.35052]; D_real [-0.3996]; Loss_D_fake [0.59963]
# 100%|██████████| 8/8 [00:02<00:00,  4.50it/s].06s/it]
# Loss_D [-0.91039]; Loss_G [0.04569]; D_real [-0.26927]; Loss_D_fake [0.64113]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].06s/it]
# Loss_D [-0.87637]; Loss_G [0.10687]; D_real [-0.23195]; Loss_D_fake [0.64443]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-1.10871]; Loss_G [0.52254]; D_real [-0.49251]; Loss_D_fake [0.6162]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-1.23387]; Loss_G [0.62802]; D_real [-0.67614]; Loss_D_fake [0.55774]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-1.00587]; Loss_G [0.57088]; D_real [-0.58224]; Loss_D_fake [0.42363]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-1.02946]; Loss_G [0.57186]; D_real [-0.57963]; Loss_D_fake [0.44983]
# 100%|██████████| 8/8 [00:02<00:00,  4.50it/s].06s/it]
# Loss_D [-0.95523]; Loss_G [0.52884]; D_real [-0.59508]; Loss_D_fake [0.36016]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-1.16395]; Loss_G [0.5923]; D_real [-0.63843]; Loss_D_fake [0.52552]
# 100%|██████████| 8/8 [00:02<00:00,  4.35it/s].06s/it]
# Loss_D [-1.09675]; Loss_G [0.52019]; D_real [-0.5959]; Loss_D_fake [0.50085]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-1.12268]; Loss_G [0.52361]; D_real [-0.48689]; Loss_D_fake [0.63579]
# 100%|██████████| 8/8 [00:02<00:00,  4.53it/s].06s/it]
# Loss_D [-1.13377]; Loss_G [0.52892]; D_real [-0.62085]; Loss_D_fake [0.51291]
# 100%|██████████| 8/8 [00:02<00:00,  4.47it/s].06s/it]
# Loss_D [-0.98909]; Loss_G [0.62631]; D_real [-0.71394]; Loss_D_fake [0.27515]
# 100%|██████████| 8/8 [00:02<00:00,  4.47it/s].06s/it]
# Loss_D [-1.10087]; Loss_G [0.59412]; D_real [-0.66617]; Loss_D_fake [0.4347]
# 100%|██████████| 8/8 [00:02<00:00,  4.39it/s].06s/it]
# Loss_D [-1.09531]; Loss_G [0.55092]; D_real [-0.61064]; Loss_D_fake [0.48467]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].06s/it]
# Loss_D [-1.08642]; Loss_G [0.56957]; D_real [-0.59964]; Loss_D_fake [0.48677]
# 100%|██████████| 8/8 [00:02<00:00,  4.49it/s].06s/it]
# Loss_D [-1.06133]; Loss_G [0.53965]; D_real [-0.5322]; Loss_D_fake [0.52913]
# 100%|██████████| 8/8 [00:02<00:00,  4.42it/s].06s/it]
# Loss_D [-1.19425]; Loss_G [0.53328]; D_real [-0.60366]; Loss_D_fake [0.59059]
# 100%|██████████| 8/8 [00:02<00:00,  4.48it/s].06s/it]
# Loss_D [-1.13547]; Loss_G [0.54926]; D_real [-0.53334]; Loss_D_fake [0.60213]
# 100%|██████████| 8/8 [00:02<00:00,  4.44it/s].06s/it]
# Loss_D [-1.17818]; Loss_G [0.52038]; D_real [-0.51586]; Loss_D_fake [0.66232]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-0.76787]; Loss_G [0.14611]; D_real [-0.07702]; Loss_D_fake [0.69086]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-1.13856]; Loss_G [0.49466]; D_real [-0.50423]; Loss_D_fake [0.63433]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-1.01437]; Loss_G [0.45401]; D_real [-0.47052]; Loss_D_fake [0.54385]
# 100%|██████████| 8/8 [00:02<00:00,  4.43it/s].06s/it]
# Loss_D [-1.21073]; Loss_G [0.56987]; D_real [-0.57547]; Loss_D_fake [0.63526]
# 100%|██████████| 8/8 [00:02<00:00,  4.46it/s].06s/it]
# Loss_D [-1.13532]; Loss_G [0.53993]; D_real [-0.63277]; Loss_D_fake [0.50255]
# 100%|██████████| 8/8 [00:02<00:00,  4.42it/s].06s/it]
# Loss_D [-1.0708]; Loss_G [0.58383]; D_real [-0.64339]; Loss_D_fake [0.42741]
# 100%|██████████| 8/8 [00:02<00:00,  4.51it/s].06s/it]
# Loss_D [-1.10633]; Loss_G [0.62118]; D_real [-0.67387]; Loss_D_fake [0.43246]
# 100%|██████████| 8/8 [00:02<00:00,  4.44it/s].06s/it]
# Loss_D [-1.0716]; Loss_G [0.60883]; D_real [-0.64293]; Loss_D_fake [0.42867]
# 100%|██████████| 8/8 [00:02<00:00,  4.52it/s].06s/it]
# Loss_D [-1.03177]; Loss_G [0.42349]; D_real [-0.56981]; Loss_D_fake [0.46197]
# 100%|██████████| 8/8 [00:02<00:00,  4.47it/s].06s/it]
# Loss_D [-0.91477]; Loss_G [0.34098]; D_real [-0.38948]; Loss_D_fake [0.52529]
# 100%|██████████| 8/8 [00:02<00:00,  4.41it/s].06s/it]
# Loss_D [-1.11704]; Loss_G [0.33505]; D_real [-0.44747]; Loss_D_fake [0.66957]
# 100%|██████████| 8/8 [00:02<00:00,  4.45it/s].06s/it]
# Loss_D [-1.13553]; Loss_G [0.49809]; D_real [-0.53541]; Loss_D_fake [0.60012]
# 100%|██████████| 8/8 [00:02<00:00,  4.41it/s].06s/it]
# Loss_D [-1.05499]; Loss_G [0.51734]; D_real [-0.54148]; Loss_D_fake [0.51352]
# 100%|██████████| 8/8 [00:02<00:00,  4.36it/s].06s/it]
# Loss_D [-1.21881]; Loss_G [0.58575]; D_real [-0.59337]; Loss_D_fake [0.62544]
# 100%|██████████| 8/8 [00:02<00:00,  4.40it/s].06s/it]
# Loss_D [-1.01612]; Loss_G [0.54549]; D_real [-0.61228]; Loss_D_fake [0.40384]
#  38%|███▊      | 3/8 [00:01<00:03,  1.56it/s].06s/it]

# %%
netD.eval(); netG.eval();
fake = netG(fixed_noise).data.cpu()
faked = np.clip(md.trn_ds.denorm(fake),0,1)

plt.figure(figsize=(9,9))
plt.imshow(gallery(faked, 8));

# %%
dims = 512
cyc = 25000
torch.save(netG.state_dict(), TMP_PATH/f'netG_{dims}_2_{cyc}.h5')
torch.save(netD.state_dict(), TMP_PATH/f'netD_{dims}_2_{cyc}.h5')
