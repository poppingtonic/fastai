# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Super resolution data

# %%
from fastai.conv_learner import *
from pathlib import Path

torch.backends.cudnn.benchmark=True

# %%
PATH = Path('data/imagenet')
PATH_TRN = PATH/'train'

# %%
fnames_full,label_arr_full,all_labels = folder_source(PATH, 'train')
fnames_full = ['/'.join(Path(fn).parts[-2:]) for fn in fnames_full]
list(zip(fnames_full[:5],label_arr_full[:5]))
# Out:
# [('n01440764/n01440764_10365.JPEG', 0),
#  ('n01440764/n01440764_11155.JPEG', 0),
#  ('n01440764/n01440764_11787.JPEG', 0),
#  ('n01440764/n01440764_12241.JPEG', 0),
#  ('n01440764/n01440764_12732.JPEG', 0)]

# %%
all_labels[:5]
# Out:
# ['n01440764', 'n01443537', 'n01491361', 'n01494475', 'n01498041']

# %%
np.random.seed(42)
keep_pct = 1.
keeps = np.random.rand(len(fnames_full)) < keep_pct
fnames = np.array(fnames_full, copy=False)[keeps]
label_arr = np.array(label_arr_full, copy=False)[keeps]

# %%
arch = vgg16
sz_hr,sz_lr = 288,72
bs = 24

# %%
class MatchedFilesDataset(FilesDataset):
    def __init__(self, fnames, y, transform, path):
        self.y=y
        assert(len(fnames)==len(y))
        super().__init__(fnames, transform, path)
    def get_y(self, i): return open_image(os.path.join(self.path, self.y[i]))
    def get_c(self): return 0

# %%
aug_tfms = [RandomFlip(tfm_y=TfmType.PIXEL),
            RandomLighting(0.1, 0.2, tfm_y=TfmType.PIXEL)]

# %%
val_idxs = get_cv_idxs(len(fnames), val_pct=min(0.01/keep_pct, 0.1))
((val_x,trn_x),(val_y,trn_y)) = split_by_idx(val_idxs, np.array(fnames), np.array(fnames))
len(val_x),len(trn_x)
# Out:
# (194, 19245)

# %%
tfms = tfms_from_model(arch, sz_lr, tfm_y=TfmType.PIXEL, aug_tfms=aug_tfms, sz_y=sz_hr, norm_y=False)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH_TRN)
md = ImageData(PATH, datasets, bs, num_workers=16, classes=None)

# %%
denorm = md.trn_ds.denorm

# %%
def show_img(ims, idx, figsize=(5,5), normed=True, ax=None):
    if ax is None: fig,ax = plt.subplots(figsize=figsize)
    if normed: ims = denorm(ims)
    else:      ims = np.rollaxis(to_np(ims),1,4)
    ax.imshow(np.clip(ims,0,1)[idx], interpolation="bilinear")
    ax.axis('off')

# %%
x,y = next(iter(md.val_dl))
x.size(),y.size()
# Out:
# (torch.Size([24, 3, 72, 72]), torch.Size([24, 3, 288, 288]))

# %%
idx=19
fig,axes = plt.subplots(1, 2, figsize=(9,5))
show_img(x,idx, ax=axes[0])
show_img(y,idx, ax=axes[1], normed=False)

# %%
batches = [next(iter(md.aug_dl)) for i in range(9)]

# %%
fig, axes = plt.subplots(3, 6, figsize=(18, 9))
for i,(x,y) in enumerate(batches):
    show_img(x,idx, ax=axes.flat[i*2])
    show_img(y,idx, ax=axes.flat[i*2+1], normed=False)

# %% [markdown]
# ## Model

# %%
def conv_bn_relu(ni, nf, kernel_size=3, bias=False, actn=True):
    pad = kernel_size//2
    layers = [
        nn.ReflectionPad2d(pad),
        nn.Conv2d(ni, nf, kernel_size, padding=0, bias=bias),
        nn.BatchNorm2d(nf)
    ]
    if actn: layers.append(nn.ReLU(inplace=True))
    return nn.Sequential(*layers)

# %%
class ResSequential(nn.Module):
    def __init__(self, *layers):
        super().__init__()
        self.m = nn.Sequential(*layers)

    def forward(self, x): return x + self.m(x)

# %%
def res_block(nf):
    return ResSequential(
        conv_bn_relu(nf, nf),
        conv_bn_relu(nf, nf, actn=False))

# %%
def upsample():
    return nn.Sequential(
        nn.Upsample(scale_factor=2),
        conv_bn_relu(64, 64))

# %%
class SrResnet(nn.Module):
    def __init__(self):
        super().__init__()
        features = [conv_bn_relu(3, 64, 9)]
        for i in range(4): features.append(res_block(64))
        features += [
            upsample(), upsample(),
            nn.ReflectionPad2d(4),
            nn.Conv2d(64, 3, kernel_size=9, bias=True, padding=0)]
        self.features = nn.Sequential(*features)
        
    def forward(self, x): return F.sigmoid(self.features(x))

# %% [markdown]
# ## Pixel loss

# %%
m = to_gpu(SrResnet())

# %%
m = nn.DataParallel(m, [0])

# %%
opt_fn = optim.Adam

# %%
learn = Learner(md, SingleModel(m), opt_fn=opt_fn)
learn.crit = F.mse_loss

# %%
learn.lr_find(start_lr=1e-4, end_lr=10000)
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   0%|          | 0/802 [00:00<?, ?it/s]
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/bmn/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/bmn/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/bmn/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#  25%|██▌       | 201/802 [02:56<08:48,  1.14it/s, loss=0.0494]

# %%
lr=1e-3

# %%
learn.fit(lr, 1, cycle_len=1, use_clr_beta=(40,10))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss
#     0      0.00794    0.008557
# [array([0.00856])]

# %%
x,y = next(iter(md.val_dl))
preds = learn.model(VV(x))

# %%
show_img(y,idx,normed=False)

# %%
show_img(preds,idx,normed=False);

# %%
show_img(x,idx);

# %% [markdown]
# ## Perceptual loss

# %%
m_vgg = vgg16(True)

# %%
blocks = [i-1 for i,o in enumerate(children(m_vgg))
              if isinstance(o,nn.MaxPool2d)]
blocks
# Out:
# [5, 12, 22, 32, 42]

# %%
[m_vgg[i] for i in blocks]
# Out:
# [ReLU(inplace), ReLU(inplace), ReLU(inplace), ReLU(inplace), ReLU(inplace)]

# %%
m_vgg = nn.Sequential(*children(m_vgg)[:23]).cuda().eval()
set_trainable(m_vgg, False)

# %%
def flatten(x): return x.view(x.size(0), -1)

# %%
class SaveFeatures():
    features=None
    def __init__(self, m): self.hook = m.register_forward_hook(self.hook_fn)
    def hook_fn(self, module, input, output): self.features = output
    def remove(self): self.hook.remove()

# %%
class FeatureLoss(nn.Module):
    def __init__(self, m, layer_ids, layer_wgts):
        super().__init__()
        self.m,self.wgts = m,layer_wgts
        self.sfs = [SaveFeatures(m[i]) for i in layer_ids]

    def forward(self, input, target, sum_layers=True):
        self.m(VV(target.data))
        targ_feat = [V(o.features.data.clone()) for o in self.sfs]
        self.m(input)
        res = [F.mse_loss(flatten(inp.features),flatten(targ))*wgt
               for inp,targ,wgt in zip(self.sfs, targ_feat, self.wgts)]
        if sum_layers: res = sum(res)
        return res
    
    def close(self):
        for o in self.sfs: o.remove()

# %%
m = to_gpu(SrResnet())
m = nn.DataParallel(m, [0])

learn = Learner(md, SingleModel(m), opt_fn=optim.Adam)

# %%
learn.crit = FeatureLoss(m_vgg, blocks[:3], [0.2,0.7,0.1])

# %%
learn.lr_find(1e-4, 1000)
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   0%|          | 0/802 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-94384fd5d122> in <module>()
# ----> 1 learn.lr_find(1e-4, 1000)
#       2 learn.sched.plot()
#
# ~/src/ai.learn/fast.ai/fastai/courses/dl2/fastai/learner.py in lr_find(self, start_lr, end_lr, wds, linear, **kwargs)
#     328         layer_opt = self.get_layer_opt(start_lr, wds)
#     329         self.sched = LR_Finder(layer_opt, len(self.data.trn_dl), end_lr, linear=linear)
# --> 330         self.fit_gen(self.model, self.data, layer_opt, 1, **kwargs)
#     331         self.load('tmp')
#     332
#
# ~/src/ai.learn/fast.ai/fastai/courses/dl2/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, use_swa, swa_start, swa_eval_freq, **kwargs)
#     232             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, fp16=self.fp16,
#     233             swa_model=self.swa_model if use_swa else None, swa_start=swa_start,
# --> 234             swa_eval_freq=swa_eval_freq, **kwargs)
#     235
#     236     def get_layer_groups(self): return self.models.get_layer_groups()
#
# ~/src/ai.learn/fast.ai/fastai/courses/dl2/fastai/model.py in fit(model, data, n_epochs, opt, crit, metrics, callbacks, stepper, swa_model, swa_start, swa_eval_freq, **kwargs)
#     127             batch_num += 1
#     128             for cb in callbacks: cb.on_batch_begin()
# --> 129             loss = model_stepper.step(V(x),V(y), epoch)
#     130             avg_loss = avg_loss * avg_mom + loss * (1-avg_mom)
#     131             debias_loss = avg_loss / (1 - avg_mom**batch_num)
#
# ~/src/ai.learn/fast.ai/fastai/courses/dl2/fastai/model.py in step(self, xs, y, epoch)
#      50         if self.fp16: self.m.zero_grad()
#      51         else: self.opt.zero_grad()
# ---> 52         loss = raw_loss = self.crit(output, y)
#      53         if self.loss_scale != 1: assert(self.fp16); loss = loss*self.loss_scale
#      54         if self.reg_fn: loss = self.reg_fn(output, xtra, raw_loss)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-30-cfe753e9a756> in forward(self, input, target, sum_layers)
#       7     def forward(self, input, target, sum_layers=True):
#       8         self.m(VV(target.data))
# ----> 9         targ_feat = [V(o.features.data.clone()) for o in self.sfs]
#      10         self.m(input)
#      11         res = [F.mse_loss(flatten(inp.features),flatten(targ))*wgt
#
# <ipython-input-30-cfe753e9a756> in <listcomp>(.0)
#       7     def forward(self, input, target, sum_layers=True):
#       8         self.m(VV(target.data))
# ----> 9         targ_feat = [V(o.features.data.clone()) for o in self.sfs]
#      10         self.m(input)
#      11         res = [F.mse_loss(flatten(inp.features),flatten(targ))*wgt
#
# RuntimeError: cuda runtime error (2) : out of memory at /opt/conda/conda-bld/pytorch_1518244421288/work/torch/lib/THC/generic/THCStorage.cu:58

# %%
lr=2e-3
wd=1e-7

# %%
learn.load('sr-samp0')

# %%
learn.fit(lr, 1, cycle_len=1, wds=wd, use_clr=(20,40,0.95,0.85))
# Out:
# A Jupyter Widget
# epoch      trn_loss   val_loss
#     0      0.005649   0.005913
# [array([0.00591])]

# %%
learn.save('sr-samp0')

# %%
learn.sched.plot_loss()

# %%
learn.fit(lr/10, 1, cycle_len=1, wds=wd, use_clr=(20,40,0.95,0.85))
# Out:
# A Jupyter Widget
#  21%|██        | 11064/52849 [1:28:29<5:34:13,  2.08it/s, loss=0.00557]

# %%
learn.save('sr')

# %%
learn.load('sr')

# %%
def plot_ds_img(idx, ax=None, figsize=(7,7), normed=True):
    if ax is None: fig,ax = plt.subplots(figsize=figsize)
    im = md.val_ds[idx][0]
    if normed: im = denorm(im)[0]
    else:      im = np.rollaxis(to_np(im),0,3)
    ax.imshow(im, interpolation="bilinear")
    ax.axis('off')

# %%
fig,axes=plt.subplots(8,4,figsize=(12,24))
for i,ax in enumerate(axes.flat): plot_ds_img(i+156,ax=ax, normed=True)

# %%
x,y=md.val_ds[183]

# %%
y=y[None]

# %%
learn.model.eval()
preds = learn.model(VV(x[None]))

# %%
learn.crit(preds, V(y), sum_layers=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-49fd68e97e22> in <module>()
# ----> 1 learn.crit(preds, V(y), sum_layers=False)
#
# TypeError: mse_loss() got an unexpected keyword argument 'sum_layers'

# %%
learn.crit.close()

# %%
show_img(preds,0, normed=False)

# %%
show_img(x[None],0)

# %%
def nrm_y(y):
    y = np.rollaxis(y,1,4)
    y,_ = tfms[1].norm(y)
    return np.rollaxis(y,3,1)

# %%
preds = learn.model(VV(nrm_y(y)))

# %%
show_img(y,0, figsize=(14,14), normed=False)

# %%
show_img(preds,0, figsize=(16,16), normed=False)

# %%
learn.save('sr')
