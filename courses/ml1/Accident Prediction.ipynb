# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.imports import *
from fastai.structured import *
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from IPython.display import display
from sklearn import metrics
# Out:
# /home/bmn/anaconda3/envs/fastai/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
PATH = 'data/AccidentPrediction/'

# %%
# !ls {PATH}
# Out:
# AccidentPrediction.Rproj  Clustering	LICENSE     README.md
# Classification		  FinalProject	mydata.csv

# %%
df_raw = pd.read_csv(Path(f'{PATH}/mydata.csv'), low_memory=False)

# %%
df_raw.describe()
# Out:
#        Police_Force  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  Day_of_Week     Location  Speed_limit  Light_Conditions  Weather_Conditions  Urban_or_Rural_Area
# count   4571.000000        4571.000000         4571.000000           4571.000000  4571.000000  4571.000000  4571.000000       4571.000000         4571.000000          4571.000000
# mean      30.989280           2.809451            1.855611              1.349595     4.113761   355.779917    38.510173          2.051630            1.551083             1.376942
# std       25.256273           0.426433            0.722066              0.768548     1.930116   258.399175    14.384181          1.733933            1.674942             0.484673
# min        1.000000           1.000000            1.000000              1.000000     1.000000     1.000000    20.000000          1.000000            1.000000             1.000000
# ...

# %%
df_raw
# Out:
#       Police_Force  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  Day_of_Week  Location  Speed_limit  Light_Conditions  Weather_Conditions  Urban_or_Rural_Area
# 0               52                  2                   1                     1            6       612           40                 6                   1                    2
# 1                1                  3                   2                     1            6        22           30                 7                   1                    1
# 2               21                  3                   1                     1            6       257           30                 4                   1                    1
# 3               35                  2                   2                     1            6       395           70                 4                   1                    2
# ...

# %%
df_raw.Accident_Severity = np.log(df_raw.Accident_Severity)

# %%
m = RandomForestRegressor(n_jobs=-1)

# %%
m.fit(df_raw.drop('Accident_Severity', axis=1), df_raw.Accident_Severity)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
df_raw.columns
# Out:
# Index(['Police_Force', 'Accident_Severity', 'Number_of_Vehicles',
#        'Number_of_Casualties', 'Day_of_Week', 'Location', 'Speed_limit',
#        'Light_Conditions', 'Weather_Conditions', 'Urban_or_Rural_Area'],
#       dtype='object')

# %%
df_raw.head()
# Out:
#    Police_Force  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  Day_of_Week  Location  Speed_limit  Light_Conditions  Weather_Conditions  Urban_or_Rural_Area
# 0            52           0.693147                   1                     1            6       612           40                 6                   1                    2
# 1             1           1.098612                   2                     1            6        22           30                 7                   1                    1
# 2            21           1.098612                   1                     1            6       257           30                 4                   1                    1
# 3            35           0.693147                   2                     1            6       395           70                 4                   1                    2
# ...

# %%
df_raw.Day_of_Week = df_raw.Day_of_Week.astype('category').cat.as_ordered()

# %%
df_raw.Location = df_raw.Location.astype('category').cat.as_ordered()

# %%
df_raw.Light_Conditions = df_raw.Light_Conditions.astype('category').cat.as_ordered()

# %%
df_raw.Weather_Conditions = df_raw.Weather_Conditions.astype('category').cat.as_ordered()

# %%
df_raw.Urban_or_Rural_Area = df_raw.Urban_or_Rural_Area.astype('category').cat.as_ordered()
